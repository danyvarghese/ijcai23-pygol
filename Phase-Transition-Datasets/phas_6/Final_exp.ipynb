# %% [markdown]
# # Test Data

# %% [markdown]
# # System 1 - Aleph

# %%
from  PyILP import *
model_aleph= aleph_learn(file="all_brel.pl", positive_example="train.f",
                     negative_example="train.n", settings="train.b")
pos=read_example("test.f")
neg=read_example("test.n")
metrics_aleph=evaluate_theory_prolog(model_aleph.hypothesis,"all_brel.pl",pos, neg)
# Out:
# [select example] [1]
# [sat] [1]
# [p(d0)]
#
# [bottom clause]
# p(A) :-
#    br0(A,B,C), br0(A,B,D), br0(A,B,E), br0(A,B,F),
#    br0(A,B,G), br0(A,B,H), br0(A,B,I), br0(A,B,J),
#    br0(A,B,K), br0(A,C,B), br0(A,C,E), br0(A,C,F),
#    br0(A,C,G), br0(A,C,H), br0(A,C,L), br0(A,C,J),
#    br0(A,C,K), br0(A,F,D), br0(A,F,H), br0(A,F,L),
#    br0(A,F,I), br0(A,F,J), br0(A,M,B), br0(A,M,D),
#    br0(A,M,E), br0(A,M,F), br0(A,M,G), br0(A,M,H),
#    br0(A,M,L), br0(A,M,I), br0(A,M,J), br0(A,M,K),
#    br0(A,G,C), br0(A,G,D), br0(A,G,E), br0(A,G,F),
#    br0(A,G,M), br0(A,G,H), br0(A,G,L), br0(A,G,I),
#    br0(A,G,J), br0(A,G,K), br0(A,H,B), br0(A,H,C),
#    br0(A,H,D), br0(A,H,E), br0(A,H,F), br0(A,H,M),
#    br0(A,H,G), br0(A,H,I), br0(A,H,J), br0(A,H,K),
#    br0(A,L,D), br0(A,L,E), br0(A,L,F), br0(A,L,M),
#    br0(A,L,G), br0(A,L,I), br0(A,L,J), br0(A,L,K),
#    br0(A,I,B), br0(A,I,C), br0(A,I,D), br0(A,I,F),
#    br0(A,I,M), br0(A,I,L), br0(A,I,J), br0(A,J,B),
#    br0(A,J,C), br0(A,J,D), br0(A,J,E), br0(A,J,F),
#    br0(A,J,M), br0(A,J,G), br0(A,J,I), br0(A,J,K),
#    br0(A,K,C), br0(A,K,D), br0(A,K,E), br0(A,K,F),
#    br0(A,K,M), br0(A,K,G), br0(A,K,L), br0(A,K,I),
#    br0(A,K,J), br0(A,D,C), br0(A,D,F), br0(A,D,M),
#    br0(A,D,H), br0(A,D,L), br0(A,D,I), br0(A,D,J),
#    br0(A,D,K), br0(A,E,C), br0(A,E,D), br0(A,E,F),
#    br0(A,E,M), br0(A,E,G), br0(A,E,H), br0(A,E,J),
#    br1(A,M,B), br1(A,M,D), br1(A,M,E), br1(A,M,F),
#    br1(A,M,G), br1(A,M,H), br1(A,M,L), br1(A,M,I),
#    br1(A,M,J), br1(A,L,B), br1(A,L,C), br1(A,L,D),
#    br1(A,L,E), br1(A,L,F), br1(A,L,M), br1(A,L,H),
#    br1(A,L,I), br1(A,L,J), br1(A,L,K), br1(A,K,B),
#    br1(A,K,C), br1(A,K,D), br1(A,K,E), br1(A,K,F),
#    br1(A,K,G), br1(A,K,H), br1(A,K,L), br1(A,K,I),
#    br1(A,K,J), br1(A,J,D), br1(A,J,E), br1(A,J,F),
#    br1(A,J,M), br1(A,J,H), br1(A,J,L), br1(A,J,I),
#    br1(A,J,K), br1(A,I,C), br1(A,I,D), br1(A,I,E),
#    br1(A,I,M), br1(A,I,G), br1(A,I,H), br1(A,I,L),
#    br1(A,H,B), br1(A,H,D), br1(A,H,E), br1(A,H,F),
#    br1(A,H,G), br1(A,H,L), br1(A,H,J), br1(A,H,K),
#    br1(A,G,C), br1(A,G,F), br1(A,G,M), br1(A,G,H),
#    br1(A,G,L), br1(A,G,J), br1(A,G,K), br1(A,F,D),
#    br1(A,F,E), br1(A,F,G), br1(A,F,H), br1(A,F,L),
#    br1(A,F,I), br1(A,F,J), br1(A,F,K), br1(A,E,B),
#    br1(A,E,C), br1(A,E,F), br1(A,E,M), br1(A,E,G),
#    br1(A,E,L), br1(A,E,K), br1(A,D,B), br1(A,D,E),
#    br1(A,D,F), br1(A,D,M), br1(A,D,G), br1(A,D,H),
#    br1(A,D,I), br1(A,C,B), br1(A,C,D), br1(A,C,E),
#    br1(A,C,M), br1(A,C,G), br1(A,C,H), br1(A,C,L),
#    br1(A,C,I), br1(A,C,J), br1(A,B,C), br1(A,B,D),
#    br1(A,B,F), br1(A,B,M), br1(A,B,G), br1(A,B,H),
#    br1(A,B,L), br1(A,B,I), br1(A,B,J), br1(A,B,K),
#    br2(A,M,B), br2(A,M,C), br2(A,M,D), br2(A,M,E),
#    br2(A,M,G), br2(A,M,H), br2(A,M,L), br2(A,M,I),
#    br2(A,M,J), br2(A,M,K), br2(A,L,B), br2(A,L,C),
#    br2(A,L,D), br2(A,L,E), br2(A,L,M), br2(A,L,G),
#    br2(A,L,H), br2(A,L,I), br2(A,L,K), br2(A,K,B),
#    br2(A,K,C), br2(A,K,F), br2(A,K,M), br2(A,K,G),
#    br2(A,K,H), br2(A,K,L), br2(A,J,B), br2(A,J,C),
#    br2(A,J,D), br2(A,J,E), br2(A,J,F), br2(A,J,M),
#    br2(A,J,G), br2(A,J,H), br2(A,J,L), br2(A,J,I),
#    br2(A,I,B), br2(A,I,D), br2(A,I,M), br2(A,I,G),
#    br2(A,I,H), br2(A,I,J), br2(A,I,K), br2(A,H,B),
#    br2(A,H,C), br2(A,H,D), br2(A,H,M), br2(A,H,L),
#    br2(A,H,I), br2(A,H,K), br2(A,G,B), br2(A,G,D),
#    br2(A,G,M), br2(A,G,H), br2(A,G,L), br2(A,G,I),
#    br2(A,G,J), br2(A,F,B), br2(A,F,C), br2(A,F,E),
#    br2(A,F,M), br2(A,F,G), br2(A,F,H), br2(A,F,L),
#    br2(A,F,I), br2(A,F,K), br2(A,E,B), br2(A,E,C),
#    br2(A,E,D), br2(A,E,M), br2(A,E,G), br2(A,E,H),
#    br2(A,E,L), br2(A,E,J), br2(A,E,K), br2(A,D,B),
#    br2(A,D,C), br2(A,D,E), br2(A,D,F), br2(A,D,M),
#    br2(A,D,G), br2(A,D,L), br2(A,D,I), br2(A,D,J),
#    br2(A,C,D), br2(A,C,E), br2(A,C,F), br2(A,C,G),
#    br2(A,C,H), br2(A,C,L), br2(A,C,I), br2(A,C,K),
#    br2(A,B,C), br2(A,B,D), br2(A,B,E), br2(A,B,H),
#    br2(A,B,L), br2(A,B,I), br2(A,B,J), br2(A,B,K),
#    br3(A,M,B), br3(A,M,C), br3(A,M,D), br3(A,M,E),
#    br3(A,M,F), br3(A,M,G), br3(A,M,H), br3(A,M,L),
#    br3(A,M,I), br3(A,L,B), br3(A,L,C), br3(A,L,E),
#    br3(A,L,F), br3(A,L,M), br3(A,L,G), br3(A,L,I),
#    br3(A,L,J), br3(A,L,K), br3(A,K,B), br3(A,K,D),
#    br3(A,K,E), br3(A,K,F), br3(A,K,G), br3(A,K,H),
#    br3(A,K,I), br3(A,J,B), br3(A,J,C), br3(A,J,E),
#    br3(A,J,F), br3(A,J,M), br3(A,J,H), br3(A,J,L),
#    br3(A,J,I), br3(A,J,K), br3(A,I,B), br3(A,I,C),
#    br3(A,I,D), br3(A,I,E), br3(A,I,F), br3(A,I,G),
#    br3(A,I,H), br3(A,I,L), br3(A,I,J), br3(A,I,K),
#    br3(A,H,B), br3(A,H,C), br3(A,H,D), br3(A,H,F),
#    br3(A,H,M), br3(A,H,G), br3(A,H,L), br3(A,H,I),
#    br3(A,H,K), br3(A,G,C), br3(A,G,D), br3(A,G,E),
#    br3(A,G,M), br3(A,G,H), br3(A,G,L), br3(A,G,I),
#    br3(A,G,J), br3(A,G,K), br3(A,F,C), br3(A,F,D),
#    br3(A,F,E), br3(A,F,M), br3(A,F,G), br3(A,F,H),
#    br3(A,F,L), br3(A,F,I), br3(A,E,D), br3(A,E,F),
#    br3(A,E,L), br3(A,E,J), br3(A,D,C), br3(A,D,E),
#    br3(A,D,H), br3(A,D,L), br3(A,D,I), br3(A,D,J),
#    br3(A,D,K), br3(A,C,D), br3(A,C,E), br3(A,C,F),
#    br3(A,C,M), br3(A,C,G), br3(A,C,H), br3(A,C,L),
#    br3(A,C,I), br3(A,C,J), br3(A,B,C), br3(A,B,D),
#    br3(A,B,E), br3(A,B,F), br3(A,B,M), br3(A,B,G),
#    br3(A,B,H), br3(A,B,L), br3(A,B,J), br3(A,B,K),
#    br4(A,M,C), br4(A,M,D), br4(A,M,E), br4(A,M,L),
#    br4(A,M,I), br4(A,L,C), br4(A,L,E), br4(A,L,F),
#    br4(A,L,M), br4(A,L,H), br4(A,L,I), br4(A,L,J),
#    br4(A,L,K), br4(A,K,C), br4(A,K,D), br4(A,K,E),
#    br4(A,K,F), br4(A,K,M), br4(A,K,G), br4(A,K,I),
#    br4(A,K,J), br4(A,J,B), br4(A,J,C), br4(A,J,D),
#    br4(A,J,E), br4(A,J,F), br4(A,J,M), br4(A,J,G),
#    br4(A,J,H), br4(A,J,L), br4(A,J,I), br4(A,J,K),
#    br4(A,I,B), br4(A,I,F), br4(A,I,M), br4(A,I,G),
#    br4(A,I,H), br4(A,I,L), br4(A,I,J), br4(A,H,B),
#    br4(A,H,C), br4(A,H,D), br4(A,H,E), br4(A,H,F),
#    br4(A,H,M), br4(A,H,G), br4(A,H,L), br4(A,H,I),
#    br4(A,G,B), br4(A,G,D), br4(A,G,E), br4(A,G,F),
#    br4(A,G,M), br4(A,G,H), br4(A,G,L), br4(A,G,I),
#    br4(A,G,J), br4(A,G,K), br4(A,F,C), br4(A,F,D),
#    br4(A,F,E), br4(A,F,H), br4(A,F,L), br4(A,F,I),
#    br4(A,F,J), br4(A,F,K), br4(A,E,B), br4(A,E,C),
#    br4(A,E,D), br4(A,E,F), br4(A,E,M), br4(A,E,H),
#    br4(A,E,L), br4(A,E,J), br4(A,E,K), br4(A,D,B),
#    br4(A,D,E), br4(A,D,F), br4(A,D,M), br4(A,D,L),
#    br4(A,D,I), br4(A,D,J), br4(A,D,K), br4(A,C,B),
#    br4(A,C,D), br4(A,C,E), br4(A,C,F), br4(A,C,M),
#    br4(A,C,G), br4(A,C,H), br4(A,C,J), br4(A,C,K),
#    br4(A,B,D), br4(A,B,F), br4(A,B,M), br4(A,B,G),
#    br4(A,B,H), br4(A,B,I), br4(A,B,J), br4(A,B,K),
#    br5(A,M,B), br5(A,M,C), br5(A,M,D), br5(A,M,E),
#    br5(A,M,G), br5(A,M,L), br5(A,M,I), br5(A,M,J),
#    br5(A,M,K), br5(A,L,B), br5(A,L,C), br5(A,L,D),
#    br5(A,L,E), br5(A,L,M), br5(A,L,G), br5(A,L,J),
#    br5(A,K,B), br5(A,K,C), br5(A,K,D), br5(A,K,F),
#    br5(A,K,M), br5(A,K,G), br5(A,K,H), br5(A,K,L),
#    br5(A,J,B), br5(A,J,C), br5(A,J,E), br5(A,J,F),
#    br5(A,J,M), br5(A,J,G), br5(A,J,H), br5(A,J,L),
#    br5(A,J,I), br5(A,I,B), br5(A,I,C), br5(A,I,F),
#    br5(A,I,M), br5(A,I,H), br5(A,I,L), br5(A,I,J),
#    br5(A,I,K), br5(A,H,B), br5(A,H,C), br5(A,H,D),
#    br5(A,H,E), br5(A,H,M), br5(A,H,G), br5(A,H,L),
#    br5(A,H,I), br5(A,H,J), br5(A,H,K), br5(A,G,B),
#    br5(A,G,C), br5(A,G,D), br5(A,G,E), br5(A,G,F),
#    br5(A,G,M), br5(A,G,H), br5(A,G,J), br5(A,G,K),
#    br5(A,F,B), br5(A,F,C), br5(A,F,D), br5(A,F,E),
#    br5(A,F,M), br5(A,F,L), br5(A,F,I), br5(A,F,J),
#    br5(A,F,K), br5(A,E,C), br5(A,E,D), br5(A,E,M),
#    br5(A,E,L), br5(A,E,I), br5(A,E,J), br5(A,E,K),
#    br5(A,D,C), br5(A,D,F), br5(A,D,I), br5(A,D,J),
#    br5(A,D,K), br5(A,C,B), br5(A,C,D), br5(A,C,E),
#    br5(A,C,F), br5(A,C,M), br5(A,C,G), br5(A,C,H),
#    br5(A,C,I), br5(A,C,J), br5(A,C,K), br5(A,B,E),
#    br5(A,B,F), br5(A,B,M), br5(A,B,G), br5(A,B,H),
#    br5(A,B,L), br5(A,B,I), br5(A,B,J), br5(A,B,K).
# [literals] [601]
# [saturation time] [0.26360146299999965]
# [reduce]
# [best label so far] [[1,0,2,1]/0]
# p(A).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,C,B).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br1(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br2(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,C,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,B,C).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br3(A,B,D).
# [67/67]
# p(A) :-
#    br0(A,B,C), br4(A,C,B).
# [67/0]
# [-------------------------------------]
# [found clause]
# p(A) :-
#    br0(A,B,C), br4(A,C,B).
# [pos cover = 67 neg cover = 0] [pos-neg] [67]
# [clause label] [[67,0,3,67]]
# [clauses constructed] [156]
# [-------------------------------------]
# [clauses constructed] [156]
# [search time] [0.08465849499999933]
# [best clause]
# p(A) :-
#    br0(A,B,C), br4(A,C,B).
# [pos cover = 67 neg cover = 0] [pos-neg] [67]
# [atoms left] [0]
# [positive examples left] [0]
# [estimated time to finish (secs)] [0.0]
#
# [theory]
#
# [Rule 1] [Pos cover = 67 Neg cover = 0]
# p(A) :-
#    br0(A,B,C), br4(A,C,B).
#
# [Training set performance]
#            Actual
#         +          -
#      +  67          0          67
# Pred
#      -  0          67          67
#
#         67          67         134
#
# Accuracy = 1
# [Training set summary] [[67,0,0,67]]
# [time taken] [0.3570661439999996]
# [total clauses constructed] [156]
# ['p(A) :-   br0(A,B,C), br4(A,C,B).']
# +----------+ Testing +----------+
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:1:
# Warning:    Redefined static procedure br0/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/aleph_bk_1.pl:82
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:40001:
# Warning:    Redefined static procedure br1/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/aleph_bk_1.pl:40082
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:80001:
# Warning:    Redefined static procedure br2/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/aleph_bk_1.pl:80082
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:120001:
# Warning:    Redefined static procedure br3/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/aleph_bk_1.pl:120082
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:160001:
# Warning:    Redefined static procedure br4/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/aleph_bk_1.pl:160082
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:180005:
# Warning:    Redefined static procedure br5/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/aleph_bk_1.pl:180086
# +---------------------+------------------+------------------+
# |       n = 66        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 33               | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 33               |
# +---------------------+------------------+------------------+
# +-------------+---+
# |   Metric    | # |
# +=============+===+
# | Accuracy    | 1 |
# +-------------+---+
# | Precision   | 1 |
# +-------------+---+
# | Sensitivity | 1 |
# +-------------+---+
# | Specificity | 1 |
# +-------------+---+
# | F1 Score    | 1 |
# +-------------+---+
# +---------------------+------------------+------------------+
# |       n = 200       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 100              | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 99               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.995 |
# +-------------+-------+
# | Precision   | 0.990 |
# +-------------+-------+
# | Sensitivity | 1     |
# +-------------+-------+
# | Specificity | 0.990 |
# +-------------+-------+
# | F1 Score    | 0.995 |
# +-------------+-------+

# %% [markdown]
# # System 2 - Metagol

# %%
from  PyILP import *
model_metagol=metagol_learn(file="all_brel_metagol.pl", positive_example="train.f", 
                                         negative_example="train.n",  shuffle=True,  
                                         test_size=0)
metrics_metagol=evaluate_theory_prolog(model_metagol.hypothesis,"all_brel.pl",pos, neg)
# Out:
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/processed_bk.pl:40:
# Warning:    Singleton variables: [C]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/processed_bk.pl:41:
# Warning:    Singleton variables: [C]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/processed_bk.pl:52:
# Warning:    Singleton variables: [B]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/processed_bk.pl:53:
# Warning:    Singleton variables: [B]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/processed_bk.pl:54:
# Warning:    Singleton variables: [C]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/processed_bk.pl:57:
# Warning:    Singleton variables: [B]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/processed_bk.pl:59:
# Warning:    Redefined static procedure br0/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:1
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/processed_bk.pl:40059:
# Warning:    Redefined static procedure br1/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:40001
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/processed_bk.pl:80059:
# Warning:    Redefined static procedure br2/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:80001
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/processed_bk.pl:120059:
# Warning:    Redefined static procedure br3/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:120001
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/processed_bk.pl:160059:
# Warning:    Redefined static procedure br4/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:160001
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/processed_bk.pl:180063:
# Warning:    Redefined static procedure br5/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:180005
# % WARNING: br6/3 does not exist
# % WARNING: br7/3 does not exist
# % WARNING: br8/3 does not exist
# % WARNING: br9/3 does not exist
# % WARNING: br10/3 does not exist
# % WARNING: br11/3 does not exist
# % WARNING: br12/3 does not exist
# % WARNING: br13/3 does not exist
# % WARNING: br14/3 does not exist
# % WARNING: br15/3 does not exist
# % WARNING: br16/3 does not exist
# % WARNING: br17/3 does not exist
# % WARNING: br18/3 does not exist
# % WARNING: br19/3 does not exist
# % WARNING: br20/3 does not exist
# % WARNING: br21/3 does not exist
# % WARNING: br22/3 does not exist
# % WARNING: br23/3 does not exist
# % WARNING: br24/3 does not exist
# % WARNING: br25/3 does not exist
# % WARNING: br26/3 does not exist
# % WARNING: br27/3 does not exist
# % WARNING: br28/3 does not exist
# % WARNING: br29/3 does not exist
# % WARNING: br30/3 does not exist
# % learning p/1
# % clauses: 1
# p(A):-br0(A,B,C),br4(A,B,C).
# ['p(A):-br0(A,B,C),br4(A,B,C)']
# +----------+ Learning +----------+
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:39:
# Warning:    Redefined static procedure metagol:metarule/6
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/processed_bk.pl:39
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:40:
# Warning:    Singleton variables: [C]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:41:
# Warning:    Singleton variables: [C]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:52:
# Warning:    Singleton variables: [B]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:53:
# Warning:    Singleton variables: [B]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:54:
# Warning:    Singleton variables: [C]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:57:
# Warning:    Singleton variables: [B]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_6/copy_bk.pl:220063:
# Warning:    Redefined static procedure p/1
# +---------------------+------------------+------------------+
# |       n = 200       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 100              | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 100              |
# +---------------------+------------------+------------------+
# +-------------+---+
# |   Metric    | # |
# +=============+===+
# | Accuracy    | 1 |
# +-------------+---+
# | Precision   | 1 |
# +-------------+---+
# | Sensitivity | 1 |
# +-------------+---+
# | Specificity | 1 |
# +-------------+---+
# | F1 Score    | 1 |
# +-------------+---+
# +---------------------+------------------+------------------+
# |       n = 200       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 100              | 2                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 98               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.990 |
# +-------------+-------+
# | Precision   | 0.980 |
# +-------------+-------+
# | Sensitivity | 1     |
# +-------------+-------+
# | Specificity | 0.980 |
# +-------------+-------+
# | F1 Score    | 0.990 |
# +-------------+-------+

# %% [markdown]
# # System 3 - PyGol

# %%
from pygolm import *
#P, N = bottom_clause_generation(file="all_brel.pl", positive_example="train.f"
                                #,negative_example="train.n", depth=1, container="dict")


Train_P, Test_P, Train_N, Test_N=pygolm_train_test_split(test_size=0)

# %%
model_pygol = pygolm_learn(Train_P, Train_N,  min_pos=2, max_neg=0, max_literals=6, 
                          optimize=True, 
                     exact_literals=True, distinct=True, key_size=1)
pos=read_example("test.f")
neg=read_example("test.n")
metrics_pygol= evaluate_theory_prolog(model_pygol.hypothesis,"all_brel.pl",pos, neg)
# Out:
# 100%|█████████████████████████████████████████| 100/100 [00:02<00:00, 41.56it/s]
# 100%|████████████████████████████████████████| 100/100 [00:00<00:00, 331.93it/s]
# +----------+ Training +----------+
# ['p(A):-br0(A,B,C),br1(A,B,C),br2(A,B,C),br3(A,B,C),br4(A,B,C),br5(A,B,C)']
# +---------------------+------------------+------------------+
# |       n = 200       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 80               | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 20               | 100              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.900 |
# +-------------+-------+
# | Precision   | 1     |
# +-------------+-------+
# | Sensitivity | 0.800 |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0.889 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 200       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 100              | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 100              |
# +---------------------+------------------+------------------+
# +-------------+---+
# |   Metric    | # |
# +=============+===+
# | Accuracy    | 1 |
# +-------------+---+
# | Precision   | 1 |
# +-------------+---+
# | Sensitivity | 1 |
# +-------------+---+
# | Specificity | 1 |
# +-------------+---+
# | F1 Score    | 1 |
# +-------------+---+

# %% [markdown]
# # System 4 - ProGolem

# %%
from help_progolem import *

# %%
# %%sh
# cat run_script.sh
# ./run_script.sh
# Out:
# yap -l run.pl > output.txt
# % Restoring file /usr/lib/Yap/startup.yss
# YAP 6.2.2 (x86_64-linux): Wed Jul 15 05:25:26 UTC 2015

# %%
model_progolem = metric_progolem_hold_out()

# %%
# %%sh
# cat run_script.sh
# ./run_script_1.sh
# Out:
# yap -l run.pl > output.txt
# % Restoring file /usr/lib/Yap/startup.yss
# YAP 6.2.2 (x86_64-linux): Wed Jul 15 05:25:26 UTC 2015

# %%
metrics_progolem = metric_progolem_hold_out_test()

# %%
d = {'Pygol': [round(metrics_pygol.accuracy,3),  
               round(model_pygol.time_learn,2)],
'Metagol_NT': [round(metrics_metagol.accuracy,3),  
               round(model_metagol.time_learn,2)],
'ProGolem': [round(metrics_progolem['accuracy'],3), 
             round(model_progolem['time'],2)],
'Aleph': [round(metrics_aleph.accuracy,3), 
          round(model_aleph.time_learn,2)]
}
print ("{:<15} {:<10} {:<10}".format('System','Accuracy','Time'))
print ("{:<15} {:<10} {:<10}".format('------','--------','----'))
for k, v in d.items():
    perc, change = v
    print ("{:<15} {:<10} {:<10}".format(k,  perc, change))
# Out:
# System          Accuracy   Time
# ------          --------   ----
# Pygol           1.0        3.03
# Metagol_NT      0.99       2.89
# ProGolem        98.0       4.2
# Aleph           0.995      3.01

# %%
#!pip3 install pyswip==0.2.10
