# %% [markdown]
# # Test Data

# %% [markdown]
# # System 1 - Aleph

# %%
from  PyILP import *
model_aleph= aleph_learn(file="all_brel.pl", positive_example="train.f",
                     negative_example="train.n", settings="train.b")
pos=read_example("test.f")
neg=read_example("test.n")
metrics_aleph=evaluate_theory_prolog(model_aleph.hypothesis,"all_brel.pl",pos, neg)
# Out:
# [select example] [1]
# [sat] [1]
# [p(d0)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.001971224000000049]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [67/67]
# [clauses constructed] [1]
# [search time] [0.0005319659999996063]
# [best clause]
# p(d0).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [66]
# [positive examples left] [66]
# [estimated time to finish (secs)] [0.03510975599997401]
# [select example] [2]
# [sat] [2]
# [p(d1)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0012081720000001184]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [66/67]
# [clauses constructed] [1]
# [search time] [0.0004601269999993107]
# [best clause]
# p(d1).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [65]
# [positive examples left] [65]
# [estimated time to finish (secs)] [0.0322430224999648]
# [select example] [3]
# [sat] [3]
# [p(d2)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.001000890000000254]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [65/67]
# [clauses constructed] [1]
# [search time] [0.0005201240000003438]
# [best clause]
# p(d2).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [64]
# [positive examples left] [64]
# [estimated time to finish (secs)] [0.03226062933331756]
# [select example] [4]
# [sat] [4]
# [p(d3)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010401250000002804]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [64/67]
# [clauses constructed] [1]
# [search time] [0.0004724999999998758]
# [best clause]
# p(d3).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [63]
# [positive examples left] [63]
# [estimated time to finish (secs)] [0.0312592927499864]
# [select example] [5]
# [sat] [5]
# [p(d4)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0008938680000003529]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [63/67]
# [clauses constructed] [1]
# [search time] [0.00037268099999998583]
# [best clause]
# p(d4).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [62]
# [positive examples left] [62]
# [estimated time to finish (secs)] [0.029231735199989117]
# [select example] [6]
# [sat] [6]
# [p(d5)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010642369999995793]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [62/67]
# [clauses constructed] [1]
# [search time] [0.0005004089999998129]
# [best clause]
# p(d5).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [61]
# [positive examples left] [61]
# [estimated time to finish (secs)] [0.02905437116665584]
# [select example] [7]
# [sat] [7]
# [p(d6)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0008716800000003744]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [61/67]
# [clauses constructed] [1]
# [search time] [0.0003780879999997211]
# [best clause]
# p(d6).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [60]
# [positive examples left] [60]
# [estimated time to finish (secs)] [0.02773624285713134]
# [select example] [8]
# [sat] [8]
# [p(d7)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010331450000000686]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [60/67]
# [clauses constructed] [1]
# [search time] [0.0004597750000003842]
# [best clause]
# p(d7).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [59]
# [positive examples left] [59]
# [estimated time to finish (secs)] [0.027255566249992924]
# [select example] [9]
# [sat] [9]
# [p(d8)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0011235730000000999]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [59/67]
# [clauses constructed] [1]
# [search time] [0.00039934700000010537]
# [best clause]
# p(d8).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [58]
# [positive examples left] [58]
# [estimated time to finish (secs)] [0.026390109555550052]
# [select example] [10]
# [sat] [10]
# [p(d9)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010291049999997526]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [58/67]
# [clauses constructed] [1]
# [search time] [0.00048417200000017147]
# [best clause]
# p(d9).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [57]
# [positive examples left] [57]
# [estimated time to finish (secs)] [0.02610137729999611]
# [select example] [11]
# [sat] [11]
# [p(d10)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0008458490000000651]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [57/67]
# [clauses constructed] [1]
# [search time] [0.0004066429999998178]
# [best clause]
# p(d10).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [56]
# [positive examples left] [56]
# [estimated time to finish (secs)] [0.02538241745454105]
# [select example] [12]
# [sat] [12]
# [p(d11)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.00112013299999969]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [56/67]
# [clauses constructed] [1]
# [search time] [0.0003628010000005233]
# [best clause]
# p(d11).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [55]
# [positive examples left] [55]
# [estimated time to finish (secs)] [0.024514567916665102]
# [select example] [13]
# [sat] [13]
# [p(d12)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010244459999997346]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [55/67]
# [clauses constructed] [1]
# [search time] [0.0004155890000001605]
# [best clause]
# p(d12).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [54]
# [positive examples left] [54]
# [estimated time to finish (secs)] [0.02394369138461463]
# [select example] [14]
# [sat] [14]
# [p(d13)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0008919430000000617]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [54/67]
# [clauses constructed] [1]
# [search time] [0.00033395399999935904]
# [best clause]
# p(d13).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [53]
# [positive examples left] [53]
# [estimated time to finish (secs)] [0.023085951999996888]
# [select example] [15]
# [sat] [15]
# [p(d14)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010293439999999876]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [53/67]
# [clauses constructed] [1]
# [search time] [0.0003982440000003251]
# [best clause]
# p(d14).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [52]
# [positive examples left] [52]
# [estimated time to finish (secs)] [0.022520922666664944]
# [select example] [16]
# [sat] [16]
# [p(d15)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010007940000003046]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [52/67]
# [clauses constructed] [1]
# [search time] [0.00037932299999976493]
# [best clause]
# p(d15).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [51]
# [positive examples left] [51]
# [estimated time to finish (secs)] [0.021916430812497667]
# [select example] [17]
# [sat] [17]
# [p(d16)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0008802149999995734]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [51/67]
# [clauses constructed] [1]
# [search time] [0.0003587259999999759]
# [best clause]
# p(d16).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [50]
# [positive examples left] [50]
# [estimated time to finish (secs)] [0.021277849999997777]
# [select example] [18]
# [sat] [18]
# [p(d17)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.000883394999999787]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [50/67]
# [clauses constructed] [1]
# [search time] [0.0003807340000001602]
# [best clause]
# p(d17).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [49]
# [positive examples left] [49]
# [estimated time to finish (secs)] [0.020730274833331713]
# [select example] [19]
# [sat] [19]
# [p(d18)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0008861210000006281]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [49/67]
# [clauses constructed] [1]
# [search time] [0.00034361500000024137]
# [best clause]
# p(d18).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [48]
# [positive examples left] [48]
# [estimated time to finish (secs)] [0.020106487578946473]
# [select example] [20]
# [sat] [20]
# [p(d19)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.000914096000000697]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [48/67]
# [clauses constructed] [1]
# [search time] [0.0003540160000001791]
# [best clause]
# p(d19).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [47]
# [positive examples left] [47]
# [estimated time to finish (secs)] [0.01953515989999959]
# [select example] [21]
# [sat] [21]
# [p(d20)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0008979699999995816]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [47/67]
# [clauses constructed] [1]
# [search time] [0.00035081600000008706]
# [best clause]
# p(d20).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [46]
# [positive examples left] [46]
# [estimated time to finish (secs)] [0.018977519047618855]
# [select example] [22]
# [sat] [22]
# [p(d21)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009634080000004985]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [46/67]
# [clauses constructed] [1]
# [search time] [0.00039335800000017684]
# [best clause]
# p(d21).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [45]
# [positive examples left] [45]
# [estimated time to finish (secs)] [0.018525698181818363]
# [select example] [23]
# [sat] [23]
# [p(d22)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009749259999995985]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [45/67]
# [clauses constructed] [1]
# [search time] [0.0004321679999996775]
# [best clause]
# p(d22).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [44]
# [positive examples left] [44]
# [estimated time to finish (secs)] [0.018153206260869116]
# [select example] [24]
# [sat] [24]
# [p(d23)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0008454650000002673]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [44/67]
# [clauses constructed] [1]
# [search time] [0.0004071290000000616]
# [best clause]
# p(d23).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [43]
# [positive examples left] [43]
# [estimated time to finish (secs)] [0.01773087979166636]
# [select example] [25]
# [sat] [25]
# [p(d24)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.000983006999999425]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [43/67]
# [clauses constructed] [1]
# [search time] [0.00042607100000058296]
# [best clause]
# p(d24).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [42]
# [positive examples left] [42]
# [estimated time to finish (secs)] [0.01734159168000069]
# [select example] [26]
# [sat] [26]
# [p(d25)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010868760000004585]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [42/67]
# [clauses constructed] [1]
# [search time] [0.00042527100000011586]
# [best clause]
# p(d25).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [41]
# [positive examples left] [41]
# [estimated time to finish (secs)] [0.01694821257692391]
# [select example] [27]
# [sat] [27]
# [p(d26)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0008458579999999216]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [41/67]
# [clauses constructed] [1]
# [search time] [0.00036532399999966714]
# [best clause]
# p(d26).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [40]
# [positive examples left] [40]
# [estimated time to finish (secs)] [0.01646366074074103]
# [select example] [28]
# [sat] [28]
# [p(d27)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009278489999999806]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [40/67]
# [clauses constructed] [1]
# [search time] [0.0003871819999998749]
# [best clause]
# p(d27).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [39]
# [positive examples left] [39]
# [estimated time to finish (secs)] [0.016018070250000096]
# [select example] [29]
# [sat] [29]
# [p(d28)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009326180000002182]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [39/67]
# [clauses constructed] [1]
# [search time] [0.000340455999999989]
# [best clause]
# p(d28).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [38]
# [positive examples left] [38]
# [estimated time to finish (secs)] [0.015515280758620765]
# [select example] [30]
# [sat] [30]
# [p(d29)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009053380000008104]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [38/67]
# [clauses constructed] [1]
# [search time] [0.00032153399999934607]
# [best clause]
# p(d29).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [37]
# [positive examples left] [37]
# [estimated time to finish (secs)] [0.01499997636666593]
# [select example] [31]
# [sat] [31]
# [p(d30)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010534830000006323]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [37/67]
# [clauses constructed] [1]
# [search time] [0.0004902309999996746]
# [best clause]
# p(d30).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [36]
# [positive examples left] [36]
# [estimated time to finish (secs)] [0.014693079483869897]
# [select example] [32]
# [sat] [32]
# [p(d31)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009764999999992696]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [36/67]
# [clauses constructed] [1]
# [search time] [0.0004373910000001757]
# [best clause]
# p(d31).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [35]
# [positive examples left] [35]
# [estimated time to finish (secs)] [0.014316930468749184]
# [select example] [33]
# [sat] [33]
# [p(d32)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009442509999999515]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [35/67]
# [clauses constructed] [1]
# [search time] [0.0003619989999998907]
# [best clause]
# p(d32).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [34]
# [positive examples left] [34]
# [estimated time to finish (secs)] [0.013859393212120331]
# [select example] [34]
# [sat] [34]
# [p(d33)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010538560000004082]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [34/67]
# [clauses constructed] [1]
# [search time] [0.00045641399999940546]
# [best clause]
# p(d33).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [33]
# [positive examples left] [33]
# [estimated time to finish (secs)] [0.013499113941175063]
# [select example] [35]
# [sat] [35]
# [p(d34)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009522460000006561]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [33/67]
# [clauses constructed] [1]
# [search time] [0.0004725939999996598]
# [best clause]
# p(d34).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [32]
# [positive examples left] [32]
# [estimated time to finish (secs)] [0.013148134399998363]
# [select example] [36]
# [sat] [36]
# [p(d35)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009922480000001954]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [32/67]
# [clauses constructed] [1]
# [search time] [0.00033588199999989854]
# [best clause]
# p(d35).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [31]
# [positive examples left] [31]
# [estimated time to finish (secs)] [0.01267267427777615]
# [select example] [37]
# [sat] [37]
# [p(d36)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010873169999996435]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [31/67]
# [clauses constructed] [1]
# [search time] [0.0004487260000001214]
# [best clause]
# p(d36).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [30]
# [positive examples left] [30]
# [estimated time to finish (secs)] [0.01229625405405262]
# [select example] [38]
# [sat] [38]
# [p(d37)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010483559999991954]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [30/67]
# [clauses constructed] [1]
# [search time] [0.00034812600000044824]
# [best clause]
# p(d37).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [29]
# [positive examples left] [29]
# [estimated time to finish (secs)] [0.01183925457894636]
# [select example] [39]
# [sat] [39]
# [p(d38)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0011442910000001305]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [29/67]
# [clauses constructed] [1]
# [search time] [0.0004199539999998336]
# [best clause]
# p(d38).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [28]
# [positive examples left] [28]
# [estimated time to finish (secs)] [0.01143940717948611]
# [select example] [40]
# [sat] [40]
# [p(d39)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009068150000004493]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [28/67]
# [clauses constructed] [1]
# [search time] [0.00033115200000022327]
# [best clause]
# p(d39).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [27]
# [positive examples left] [27]
# [estimated time to finish (secs)] [0.010978613099999146]
# [select example] [41]
# [sat] [41]
# [p(d40)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.001053801999999493]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [27/67]
# [clauses constructed] [1]
# [search time] [0.000371188999999994]
# [best clause]
# p(d40).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [26]
# [positive examples left] [26]
# [estimated time to finish (secs)] [0.010549532341462609]
# [select example] [42]
# [sat] [42]
# [p(d41)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0008471499999993526]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [26/67]
# [clauses constructed] [1]
# [search time] [0.00032967900000002714]
# [best clause]
# p(d41).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [25]
# [positive examples left] [25]
# [estimated time to finish (secs)] [0.010098499999999259]
# [select example] [43]
# [sat] [43]
# [p(d42)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009220220000001333]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [25/67]
# [clauses constructed] [1]
# [search time] [0.00031571500000016073]
# [best clause]
# p(d42).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [24]
# [positive examples left] [24]
# [estimated time to finish (secs)] [0.00964531813953428]
# [select example] [44]
# [sat] [44]
# [p(d43)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0011168979999993667]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [24/67]
# [clauses constructed] [1]
# [search time] [0.00036652499999956234]
# [best clause]
# p(d43).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [23]
# [positive examples left] [23]
# [estimated time to finish (secs)] [0.00922494454545375]
# [select example] [45]
# [sat] [45]
# [p(d44)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010199650000002336]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [23/67]
# [clauses constructed] [1]
# [search time] [0.00031359399999963955]
# [best clause]
# p(d44).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [22]
# [positive examples left] [22]
# [estimated time to finish (secs)] [0.008781086844443524]
# [select example] [46]
# [sat] [46]
# [p(d45)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010447280000001058]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [22/67]
# [clauses constructed] [1]
# [search time] [0.000365774000000485]
# [best clause]
# p(d45).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [21]
# [positive examples left] [21]
# [estimated time to finish (secs)] [0.008366714086955884]
# [select example] [47]
# [sat] [47]
# [p(d46)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009618820000003581]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [21/67]
# [clauses constructed] [1]
# [search time] [0.0004155199999997805]
# [best clause]
# p(d46).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [20]
# [positive examples left] [20]
# [estimated time to finish (secs)] [0.007975577872339738]
# [select example] [48]
# [sat] [48]
# [p(d47)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0008609069999998553]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [20/67]
# [clauses constructed] [1]
# [search time] [0.00034142300000006287]
# [best clause]
# p(d47).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [19]
# [positive examples left] [19]
# [estimated time to finish (secs)] [0.007554095604166052]
# [select example] [49]
# [sat] [49]
# [p(d48)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0008860899999998395]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [19/67]
# [clauses constructed] [1]
# [search time] [0.00034599499999998784]
# [best clause]
# p(d48).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [18]
# [positive examples left] [18]
# [estimated time to finish (secs)] [0.007137560571427996]
# [select example] [50]
# [sat] [50]
# [p(d49)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009528970000003412]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [18/67]
# [clauses constructed] [1]
# [search time] [0.00029866099999953377]
# [best clause]
# p(d49).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [17]
# [positive examples left] [17]
# [estimated time to finish (secs)] [0.006707753579999309]
# [select example] [51]
# [sat] [51]
# [p(d50)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009134670000001677]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [17/67]
# [clauses constructed] [1]
# [search time] [0.0003053660000000846]
# [best clause]
# p(d50).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [16]
# [positive examples left] [16]
# [estimated time to finish (secs)] [0.006285193098038605]
# [select example] [52]
# [sat] [52]
# [p(d51)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009170720000000188]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [16/67]
# [clauses constructed] [1]
# [search time] [0.00030610800000019367]
# [best clause]
# p(d51).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [15]
# [positive examples left] [15]
# [estimated time to finish (secs)] [0.005867354134614879]
# [select example] [53]
# [sat] [53]
# [p(d52)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009203499999994591]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [15/67]
# [clauses constructed] [1]
# [search time] [0.00037684099999957255]
# [best clause]
# p(d52).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [14]
# [positive examples left] [14]
# [estimated time to finish (secs)] [0.005472415622640933]
# [select example] [54]
# [sat] [54]
# [p(d53)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0012064399999998088]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [14/67]
# [clauses constructed] [1]
# [search time] [0.000348550000000003]
# [best clause]
# p(d53).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [13]
# [positive examples left] [13]
# [estimated time to finish (secs)] [0.005071336592592068]
# [select example] [55]
# [sat] [55]
# [p(d54)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0010964109999997973]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [13/67]
# [clauses constructed] [1]
# [search time] [0.0003651419999997074]
# [best clause]
# p(d54).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [12]
# [positive examples left] [12]
# [estimated time to finish (secs)] [0.004675787781817643]
# [select example] [56]
# [sat] [56]
# [p(d55)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0008987099999995252]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [12/67]
# [clauses constructed] [1]
# [search time] [0.0003129719999996894]
# [best clause]
# p(d55).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [11]
# [positive examples left] [11]
# [estimated time to finish (secs)] [0.004271077249999454]
# [select example] [57]
# [sat] [57]
# [p(d56)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009516600000001318]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [11/67]
# [clauses constructed] [1]
# [search time] [0.00030040900000027904]
# [best clause]
# p(d56).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [10]
# [positive examples left] [10]
# [estimated time to finish (secs)] [0.0038673815789469295]
# [select example] [58]
# [sat] [58]
# [p(d57)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.000975535999999444]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [10/67]
# [clauses constructed] [1]
# [search time] [0.0003008900000001091]
# [best clause]
# p(d57).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [9]
# [positive examples left] [9]
# [estimated time to finish (secs)] [0.0034673221551720424]
# [select example] [59]
# [sat] [59]
# [p(d58)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009204099999999826]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [9/67]
# [clauses constructed] [1]
# [search time] [0.000404532000000124]
# [best clause]
# p(d58).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [8]
# [positive examples left] [8]
# [estimated time to finish (secs)] [0.003084677559321726]
# [select example] [60]
# [sat] [60]
# [p(d59)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009528459999996741]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [8/67]
# [clauses constructed] [1]
# [search time] [0.00038880000000052206]
# [best clause]
# p(d59).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [7]
# [positive examples left] [7]
# [estimated time to finish (secs)] [0.0026994679833331294]
# [select example] [61]
# [sat] [61]
# [p(d60)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009682019999992519]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [7/67]
# [clauses constructed] [1]
# [search time] [0.00031216399999944855]
# [best clause]
# p(d60).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [6]
# [positive examples left] [6]
# [estimated time to finish (secs)] [0.0023066027213112495]
# [select example] [62]
# [sat] [62]
# [p(d61)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.001091502999999605]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [6/67]
# [clauses constructed] [1]
# [search time] [0.00038353099999977047]
# [best clause]
# p(d61).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [5]
# [positive examples left] [5]
# [estimated time to finish (secs)] [0.0019220961290320542]
# [select example] [63]
# [sat] [63]
# [p(d62)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009366789999996072]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [5/67]
# [clauses constructed] [1]
# [search time] [0.00030286099999976557]
# [best clause]
# p(d62).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [4]
# [positive examples left] [4]
# [estimated time to finish (secs)] [0.001532498603174428]
# [select example] [64]
# [sat] [64]
# [p(d63)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009008769999994115]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [4/67]
# [clauses constructed] [1]
# [search time] [0.0003083240000005816]
# [best clause]
# p(d63).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [3]
# [positive examples left] [3]
# [estimated time to finish (secs)] [0.0011458676718748978]
# [select example] [65]
# [sat] [65]
# [p(d64)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.000921305999999511]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [3/67]
# [clauses constructed] [1]
# [search time] [0.0003002670000000762]
# [best clause]
# p(d64).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [2]
# [positive examples left] [2]
# [estimated time to finish (secs)] [0.0007613982769230122]
# [select example] [66]
# [sat] [66]
# [p(d65)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.0009459830000002611]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [2/67]
# [clauses constructed] [1]
# [search time] [0.0002977580000003144]
# [best clause]
# p(d65).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [1]
# [positive examples left] [1]
# [estimated time to finish (secs)] [0.0003794424545454274]
# [select example] [67]
# [sat] [67]
# [p(d66)]
#
# [bottom clause]
# p(A).
# [literals] [1]
# [saturation time] [0.000888521000000253]
# [reduce]
# [best label so far] [[1,0,2,0]/0]
# p(A).
# [clauses constructed] [1]
# [search time] [7.956099999972821e-5]
# [best clause]
# p(d66).
# [pos cover = 1 neg cover = 0] [compression] [0]
# [atoms left] [0]
# [positive examples left] [0]
# [estimated time to finish (secs)] [0.0]
#
# [theory]
#
# [Rule 1] [Pos cover = 1 Neg cover = 0]
# p(d0).
#
# [Rule 2] [Pos cover = 1 Neg cover = 0]
# p(d1).
#
# [Rule 3] [Pos cover = 1 Neg cover = 0]
# p(d2).
#
# [Rule 4] [Pos cover = 1 Neg cover = 0]
# p(d3).
#
# [Rule 5] [Pos cover = 1 Neg cover = 0]
# p(d4).
#
# [Rule 6] [Pos cover = 1 Neg cover = 0]
# p(d5).
#
# [Rule 7] [Pos cover = 1 Neg cover = 0]
# p(d6).
#
# [Rule 8] [Pos cover = 1 Neg cover = 0]
# p(d7).
#
# [Rule 9] [Pos cover = 1 Neg cover = 0]
# p(d8).
#
# [Rule 10] [Pos cover = 1 Neg cover = 0]
# p(d9).
#
# [Rule 11] [Pos cover = 1 Neg cover = 0]
# p(d10).
#
# [Rule 12] [Pos cover = 1 Neg cover = 0]
# p(d11).
#
# [Rule 13] [Pos cover = 1 Neg cover = 0]
# p(d12).
#
# [Rule 14] [Pos cover = 1 Neg cover = 0]
# p(d13).
#
# [Rule 15] [Pos cover = 1 Neg cover = 0]
# p(d14).
#
# [Rule 16] [Pos cover = 1 Neg cover = 0]
# p(d15).
#
# [Rule 17] [Pos cover = 1 Neg cover = 0]
# p(d16).
#
# [Rule 18] [Pos cover = 1 Neg cover = 0]
# p(d17).
#
# [Rule 19] [Pos cover = 1 Neg cover = 0]
# p(d18).
#
# [Rule 20] [Pos cover = 1 Neg cover = 0]
# p(d19).
#
# [Rule 21] [Pos cover = 1 Neg cover = 0]
# p(d20).
#
# [Rule 22] [Pos cover = 1 Neg cover = 0]
# p(d21).
#
# [Rule 23] [Pos cover = 1 Neg cover = 0]
# p(d22).
#
# [Rule 24] [Pos cover = 1 Neg cover = 0]
# p(d23).
#
# [Rule 25] [Pos cover = 1 Neg cover = 0]
# p(d24).
#
# [Rule 26] [Pos cover = 1 Neg cover = 0]
# p(d25).
#
# [Rule 27] [Pos cover = 1 Neg cover = 0]
# p(d26).
#
# [Rule 28] [Pos cover = 1 Neg cover = 0]
# p(d27).
#
# [Rule 29] [Pos cover = 1 Neg cover = 0]
# p(d28).
#
# [Rule 30] [Pos cover = 1 Neg cover = 0]
# p(d29).
#
# [Rule 31] [Pos cover = 1 Neg cover = 0]
# p(d30).
#
# [Rule 32] [Pos cover = 1 Neg cover = 0]
# p(d31).
#
# [Rule 33] [Pos cover = 1 Neg cover = 0]
# p(d32).
#
# [Rule 34] [Pos cover = 1 Neg cover = 0]
# p(d33).
#
# [Rule 35] [Pos cover = 1 Neg cover = 0]
# p(d34).
#
# [Rule 36] [Pos cover = 1 Neg cover = 0]
# p(d35).
#
# [Rule 37] [Pos cover = 1 Neg cover = 0]
# p(d36).
#
# [Rule 38] [Pos cover = 1 Neg cover = 0]
# p(d37).
#
# [Rule 39] [Pos cover = 1 Neg cover = 0]
# p(d38).
#
# [Rule 40] [Pos cover = 1 Neg cover = 0]
# p(d39).
#
# [Rule 41] [Pos cover = 1 Neg cover = 0]
# p(d40).
#
# [Rule 42] [Pos cover = 1 Neg cover = 0]
# p(d41).
#
# [Rule 43] [Pos cover = 1 Neg cover = 0]
# p(d42).
#
# [Rule 44] [Pos cover = 1 Neg cover = 0]
# p(d43).
#
# [Rule 45] [Pos cover = 1 Neg cover = 0]
# p(d44).
#
# [Rule 46] [Pos cover = 1 Neg cover = 0]
# p(d45).
#
# [Rule 47] [Pos cover = 1 Neg cover = 0]
# p(d46).
#
# [Rule 48] [Pos cover = 1 Neg cover = 0]
# p(d47).
#
# [Rule 49] [Pos cover = 1 Neg cover = 0]
# p(d48).
#
# [Rule 50] [Pos cover = 1 Neg cover = 0]
# p(d49).
#
# [Rule 51] [Pos cover = 1 Neg cover = 0]
# p(d50).
#
# [Rule 52] [Pos cover = 1 Neg cover = 0]
# p(d51).
#
# [Rule 53] [Pos cover = 1 Neg cover = 0]
# p(d52).
#
# [Rule 54] [Pos cover = 1 Neg cover = 0]
# p(d53).
#
# [Rule 55] [Pos cover = 1 Neg cover = 0]
# p(d54).
#
# [Rule 56] [Pos cover = 1 Neg cover = 0]
# p(d55).
#
# [Rule 57] [Pos cover = 1 Neg cover = 0]
# p(d56).
#
# [Rule 58] [Pos cover = 1 Neg cover = 0]
# p(d57).
#
# [Rule 59] [Pos cover = 1 Neg cover = 0]
# p(d58).
#
# [Rule 60] [Pos cover = 1 Neg cover = 0]
# p(d59).
#
# [Rule 61] [Pos cover = 1 Neg cover = 0]
# p(d60).
#
# [Rule 62] [Pos cover = 1 Neg cover = 0]
# p(d61).
#
# [Rule 63] [Pos cover = 1 Neg cover = 0]
# p(d62).
#
# [Rule 64] [Pos cover = 1 Neg cover = 0]
# p(d63).
#
# [Rule 65] [Pos cover = 1 Neg cover = 0]
# p(d64).
#
# [Rule 66] [Pos cover = 1 Neg cover = 0]
# p(d65).
#
# [Rule 67] [Pos cover = 1 Neg cover = 0]
# p(d66).
#
# [Training set performance]
#            Actual
#         +          -
#      +  67          0          67
# Pred
#      -  0          67          67
#
#         67          67         134
#
# Accuracy = 1
# [Training set summary] [[67,0,0,67]]
# [time taken] [0.12621781899999984]
# [total clauses constructed] [67]
# ['p(d0).', 'p(d1).', 'p(d2).', 'p(d3).', 'p(d4).', 'p(d5).', 'p(d6).', 'p(d7).', 'p(d8).', 'p(d9).', 'p(d10).', 'p(d11).', 'p(d12).', 'p(d13).', 'p(d14).', 'p(d15).', 'p(d16).', 'p(d17).', 'p(d18).', 'p(d19).', 'p(d20).', 'p(d21).', 'p(d22).', 'p(d23).', 'p(d24).', 'p(d25).', 'p(d26).', 'p(d27).', 'p(d28).', 'p(d29).', 'p(d30).', 'p(d31).', 'p(d32).', 'p(d33).', 'p(d34).', 'p(d35).', 'p(d36).', 'p(d37).', 'p(d38).', 'p(d39).', 'p(d40).', 'p(d41).', 'p(d42).', 'p(d43).', 'p(d44).', 'p(d45).', 'p(d46).', 'p(d47).', 'p(d48).', 'p(d49).', 'p(d50).', 'p(d51).', 'p(d52).', 'p(d53).', 'p(d54).', 'p(d55).', 'p(d56).', 'p(d57).', 'p(d58).', 'p(d59).', 'p(d60).', 'p(d61).', 'p(d62).', 'p(d63).', 'p(d64).', 'p(d65).', 'p(d66).']
# +----------+ Testing +----------+
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: Unknown procedure: aleph:reset_succ/0
# Warning:   However, there are definitions for:
# Warning:         aleph:reset_succ/1
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:1:
# Warning:    Redefined static procedure br0/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/aleph_bk_1.pl:79
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:40001:
# Warning:    Redefined static procedure br1/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/aleph_bk_1.pl:40079
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:71264:
# Warning:    Redefined static procedure br2/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/aleph_bk_1.pl:71342
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:111264:
# Warning:    Redefined static procedure br3/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/aleph_bk_1.pl:111342
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:151264:
# Warning:    Redefined static procedure br4/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/aleph_bk_1.pl:151342
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:191264:
# Warning:    Redefined static procedure br5/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/aleph_bk_1.pl:191342
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:231264:
# Warning:    Redefined static procedure br6/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/aleph_bk_1.pl:231342
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:271264:
# Warning:    Redefined static procedure br7/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/aleph_bk_1.pl:271342
# +---------------------+------------------+------------------+
# |       n = 66        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 0                | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 33               | 33               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.500 |
# +-------------+-------+
# | Precision   | None  |
# +-------------+-------+
# | Sensitivity | 0     |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0     |
# +-------------+-------+
# +---------------------+------------------+------------------+
# |       n = 200       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 0                | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 100              | 100              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.500 |
# +-------------+-------+
# | Precision   | None  |
# +-------------+-------+
# | Sensitivity | 0     |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0     |
# +-------------+-------+

# %% [markdown]
# # System 2 - Metagol

# %%
from  PyILP import *
model_metagol=metagol_learn(file="all_brel_metagol.pl", positive_example="train.f", 
                                         negative_example="train.n",  shuffle=True,  
                                         test_size=0)
metrics_metagol=evaluate_theory_prolog(model_metagol.hypothesis,"all_brel.pl",pos, neg)
# Out:
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:42:
# Warning:    Singleton variables: [C]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:43:
# Warning:    Singleton variables: [C]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:54:
# Warning:    Singleton variables: [B]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:55:
# Warning:    Singleton variables: [B]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:56:
# Warning:    Singleton variables: [C]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:59:
# Warning:    Singleton variables: [B]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:61:
# Warning:    Redefined static procedure br0/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:1
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:40061:
# Warning:    Redefined static procedure br1/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:40001
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:71324:
# Warning:    Redefined static procedure br2/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:71264
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:111324:
# Warning:    Redefined static procedure br3/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:111264
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:151324:
# Warning:    Redefined static procedure br4/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:151264
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:191324:
# Warning:    Redefined static procedure br5/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:191264
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:231324:
# Warning:    Redefined static procedure br6/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:231264
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:271324:
# Warning:    Redefined static procedure br7/3
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:271264
# % WARNING: br8/3 does not exist
# % WARNING: br9/3 does not exist
# % WARNING: br10/3 does not exist
# % WARNING: br11/3 does not exist
# % WARNING: br12/3 does not exist
# % WARNING: br13/3 does not exist
# % WARNING: br14/3 does not exist
# % WARNING: br15/3 does not exist
# % WARNING: br16/3 does not exist
# % WARNING: br17/3 does not exist
# % WARNING: br18/3 does not exist
# % WARNING: br19/3 does not exist
# % WARNING: br20/3 does not exist
# % WARNING: br21/3 does not exist
# % WARNING: br22/3 does not exist
# % WARNING: br23/3 does not exist
# % WARNING: br24/3 does not exist
# % WARNING: br25/3 does not exist
# % WARNING: br26/3 does not exist
# % WARNING: br27/3 does not exist
# % WARNING: br28/3 does not exist
# % WARNING: br29/3 does not exist
# % WARNING: br30/3 does not exist
# % learning p/1
# % clauses: 1
# % clauses: 2
# % clauses: 3
# p(A):-br0(A,B,C),p_1(A,B,C).
# p_1(A,B,C):-br1(A,B,C),p_2(A,B,C).
# p_2(A,B,C):-br2(A,B,C),br1(A,C,B).
# ['p(A):-br0(A,B,C),p_1(A,B,C)', 'p_1(A,B,C):-br1(A,B,C),p_2(A,B,C)', 'p_2(A,B,C):-br2(A,B,C),br1(A,C,B)']
# +----------+ Learning +----------+
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:41:
# Warning:    Redefined static procedure metagol:metarule/6
# Warning:    Previously defined at /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/processed_bk.pl:41
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:42:
# Warning:    Singleton variables: [C]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:43:
# Warning:    Singleton variables: [C]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:54:
# Warning:    Singleton variables: [B]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:55:
# Warning:    Singleton variables: [B]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:56:
# Warning:    Singleton variables: [C]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:59:
# Warning:    Singleton variables: [B]
# Warning: /home/dv/Documents/pygol_2023/IJCAI_2023/phas_8/copy_bk.pl:311324:
# Warning:    Redefined static procedure p/1
# +---------------------+------------------+------------------+
# |       n = 200       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 100              | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 100              |
# +---------------------+------------------+------------------+
# +-------------+---+
# |   Metric    | # |
# +=============+===+
# | Accuracy    | 1 |
# +-------------+---+
# | Precision   | 1 |
# +-------------+---+
# | Sensitivity | 1 |
# +-------------+---+
# | Specificity | 1 |
# +-------------+---+
# | F1 Score    | 1 |
# +-------------+---+
# +---------------------+------------------+------------------+
# |       n = 200       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 100              | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 100              |
# +---------------------+------------------+------------------+
# +-------------+---+
# |   Metric    | # |
# +=============+===+
# | Accuracy    | 1 |
# +-------------+---+
# | Precision   | 1 |
# +-------------+---+
# | Sensitivity | 1 |
# +-------------+---+
# | Specificity | 1 |
# +-------------+---+
# | F1 Score    | 1 |
# +-------------+---+

# %% [markdown]
# # System 3 - PyGol

# %%
from pygolm import *
#P, N = bottom_clause_generation(file="all_brel.pl", positive_example="train.f"
                              # ,negative_example="train.n", depth=1, container="dict")


Train_P, Test_P, Train_N, Test_N=pygolm_train_test_split(test_size=0)

# %%
model_pygol = pygolm_learn(Train_P, Train_N, min_pos=1, max_neg=100, max_literals=8, 
                          optimize=True, 
                     exact_literals=True, distinct=True, key_size=1)
pos=read_example("test.f")
neg=read_example("test.n")
metrics_pygol= evaluate_theory_prolog(model_pygol.hypothesis,"all_brel.pl",pos, neg)
# Out:
# [['p', 'br0'], ['p', 'br1'], ['p', 'br2'], ['p', 'br3'], ['p', 'br4'], ['p', 'br5'], ['p', 'br6'], ['p', 'br7'], ['br0', 'br0'], ['br0', 'br1'], ['br0', 'br2'], ['br0', 'br3'], ['br0', 'br4'], ['br0', 'br5'], ['br0', 'br6'], ['br0', 'br7'], ['br1', 'br1'], ['br1', 'br2'], ['br1', 'br3'], ['br1', 'br4'], ['br1', 'br5'], ['br1', 'br6'], ['br1', 'br7'], ['br2', 'br2'], ['br2', 'br3'], ['br2', 'br4'], ['br2', 'br5'], ['br2', 'br6'], ['br2', 'br7'], ['br3', 'br3'], ['br3', 'br4'], ['br3', 'br5'], ['br3', 'br6'], ['br3', 'br7'], ['br4', 'br4'], ['br4', 'br5'], ['br4', 'br6'], ['br4', 'br7'], ['br5', 'br5'], ['br5', 'br6'], ['br5', 'br7'], ['br6', 'br6'], ['br6', 'br7'], ['br7', 'br7']]
# --- ['p(A):-br0(B,C,D)&br1(E,F,G)&br2(H,I,J)&br3(K,L,M)&br4(N,O,P)&br5(Q,R,S)&br6(T,U,V)&br7(W,X,Y)']
# 100%|███████████████████████████████████████| 100/100 [00:00<00:00, 1057.64it/s]
# 100%|███████████████████████████████████████| 100/100 [00:00<00:00, 1060.55it/s]
# +----------+ Hypothesis +----------+
# ['p(A):-br0(A,B,C),br1(A,B,C),br2(A,B,C),br3(A,B,C),br4(A,B,C),br5(A,B,C),br6(A,B,C),br7(A,B,C)', 'p(A):-br0(A,B,C),br1(A,B,C),br2(A,B,C),br3(A,B,C),br4(A,B,D),br5(A,B,D),br6(A,B,C),br7(A,B,C)', 'p(A):-br0(A,B,C),br1(A,B,C),br2(A,B,C),br3(A,B,C),br4(A,B,C),br5(A,B,C),br6(A,B,C),br7(A,B,D)', 'p(A):-br0(A,B,C),br1(A,B,C),br2(A,B,C),br3(A,B,C),br4(A,B,C),br5(A,B,C),br6(A,B,D),br7(A,B,C)', 'p(A):-br0(A,B,C),br1(A,B,C),br2(A,B,C),br3(A,B,D),br4(A,B,C),br5(A,B,C),br6(A,B,C),br7(A,B,C)']
# +---------------------+------------------+------------------+
# |       n = 200       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 100              | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 99               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.995 |
# +-------------+-------+
# | Precision   | 0.990 |
# +-------------+-------+
# | Sensitivity | 1     |
# +-------------+-------+
# | Specificity | 0.990 |
# +-------------+-------+
# | F1 Score    | 0.995 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 200       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 100              | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 100              |
# +---------------------+------------------+------------------+
# +-------------+---+
# |   Metric    | # |
# +=============+===+
# | Accuracy    | 1 |
# +-------------+---+
# | Precision   | 1 |
# +-------------+---+
# | Sensitivity | 1 |
# +-------------+---+
# | Specificity | 1 |
# +-------------+---+
# | F1 Score    | 1 |
# +-------------+---+

# %% [markdown]
# # System 4 - ProGolem

# %%
from help_progolem import *

# %%
# %%sh
# cat run_script.sh
# ./run_script.sh
# Out:
# yap -l run.pl > output.txt
# % Restoring file /usr/lib/Yap/startup.yss
# YAP 6.2.2 (x86_64-linux): Wed Jul 15 05:25:26 UTC 2015

# %%
model_progolem = metric_progolem_hold_out()

# %%
# %%sh
# cat run_script.sh
# ./run_script_1.sh
# Out:
# yap -l run.pl > output.txt
# % Restoring file /usr/lib/Yap/startup.yss
# YAP 6.2.2 (x86_64-linux): Wed Jul 15 05:25:26 UTC 2015

# %%
metrics_progolem = metric_progolem_hold_out_test()

# %%
d = {'Pygol': [round(metrics_pygol.accuracy,3),  
               round(model_pygol.time_learn,2)],
'Metagol_NT': [round(metrics_metagol.accuracy,3),  
              round(model_metagol.time_learn,2)],
'ProGolem': [round(metrics_progolem['accuracy'],3), 
             round(model_progolem['time'],2)],
'Aleph': [round(metrics_aleph.accuracy,3), 
          round(model_aleph.time_learn,2)]
}
print ("{:<15} {:<10} {:<10}".format('System','Accuracy','Time'))
print ("{:<15} {:<10} {:<10}".format('------','--------','----'))
for k, v in d.items():
    perc, change = v
    print ("{:<15} {:<10} {:<10}".format(k,  perc, change))
# Out:
# System          Accuracy   Time
# ------          --------   ----
# Pygol           1.0        1.94
# Metagol_NT      1.0        290.82
# ProGolem        97.5       13.91
# Aleph           0.5        3.69

# %%
#!pip3 install pyswip==0.2.10
