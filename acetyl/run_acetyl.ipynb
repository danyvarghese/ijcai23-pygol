# %% [markdown]
# # Import Packages

# %%
from pygol import *
from  PyILP import *
from help_progolem import *

# %% [markdown]
# # Parameter Settings

# %%
"""
Clause Length = 3
Min. Pos      = 2
Max. Noise    = 10
Evl.Function  = coverage 
"""
# Out:
# '\nClause Length = 3\nMin. Pos      = 2\nMax. Noise    = 10\nEvl.Function  = coverage \n'

# %% [markdown]
# # System 1 - Aleph

# %%
model_aleph=aleph_cross_validation(file="BK.pl", settings="modes.pl",  CV=10,  shuffle=True, positive_example="pos_example.f", 
                                       negative_example="neg_example.n")
# Out:
# ['great(A,B) :-   r_subst_1(A,C), ring_subst_2(B,D).', 'great(A,B) :-   r_subst_1(A,C), ring_subst_3(B,D).', 'great(A,B) :-   x_subst(A,C,D), ring_subst_4(A,E).', 'great(A,B) :-   r_subst_1(A,C), n_val(B,D).', 'great(A,B) :-   ring_subst_3(B,C), ring_subst_5(A,D).', 'great(A,B) :-   x_subst(A,C,D), ring_subst_4(B,D).', 'great(A,B) :-   ring_subst_4(B,C), n_val(A,D).', 'great(A,B) :-   ring_subst_2(B,C), ring_subst_5(A,D).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 16               | 4                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 44               | 69               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.639 |
# +-------------+-------+
# | Precision   | 0.800 |
# +-------------+-------+
# | Sensitivity | 0.267 |
# +-------------+-------+
# | Specificity | 0.945 |
# +-------------+-------+
# | F1 Score    | 0.400 |
# +-------------+-------+
# ['great(A,B) :-   x_subst(A,C,D), ring_subst_4(A,E).', 'great(A,B) :-   r_subst_1(A,C), ring_subst_2(B,D).', 'great(A,B) :-   r_subst_1(A,C), ring_subst_4(B,D).', 'great(A,B) :-   ring_subst_3(B,C), ring_subst_5(A,D).', 'great(A,B) :-   ring_subst_2(B,C), ring_subst_5(A,D).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 18               | 7                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 42               | 66               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.632 |
# +-------------+-------+
# | Precision   | 0.720 |
# +-------------+-------+
# | Sensitivity | 0.300 |
# +-------------+-------+
# | Specificity | 0.904 |
# +-------------+-------+
# | F1 Score    | 0.424 |
# +-------------+-------+
# ['great(A,B) :-   x_subst(A,C,D), ring_subst_4(A,E).', 'great(A,B) :-   r_subst_1(A,C), ring_subst_2(B,D).', 'great(A,B) :-   r_subst_1(A,C), ring_subst_4(B,D).', 'great(A,B) :-   x_subst(A,C,D), ring_subst_3(B,D).', 'great(A,B) :-   r_subst_1(A,C), n_val(B,D).', 'great(A,B) :-   ring_subst_3(B,C), ring_subst_5(A,D).', 'great(A,B) :-   ring_subst_2(B,C), ring_subst_5(A,D).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 18               | 4                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 42               | 69               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.654 |
# +-------------+-------+
# | Precision   | 0.818 |
# +-------------+-------+
# | Sensitivity | 0.300 |
# +-------------+-------+
# | Specificity | 0.945 |
# +-------------+-------+
# | F1 Score    | 0.439 |
# +-------------+-------+
# ['great(A,B) :-   x_subst(A,C,D), ring_subst_4(A,E).', 'great(A,B) :-   r_subst_1(A,C), ring_subst_2(B,D).', 'great(A,B) :-   ring_subst_4(B,C), n_val(A,D).', 'great(A,B) :-   x_subst(A,C,D), ring_subst_3(B,D).', 'great(A,B) :-   r_subst_1(A,C), n_val(B,D).', 'great(A,B) :-   ring_substitutions(B,C), ring_subst_5(A,D).', 'great(A,B) :-   x_subst(B,C,D), ring_subst_2(B,E).', 'great(A,B) :-   x_subst(A,C,D), ring_subst_4(B,D).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 17               | 11               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 43               | 62               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.594 |
# +-------------+-------+
# | Precision   | 0.607 |
# +-------------+-------+
# | Sensitivity | 0.283 |
# +-------------+-------+
# | Specificity | 0.849 |
# +-------------+-------+
# | F1 Score    | 0.386 |
# +-------------+-------+
# ['great(A,B) :-   x_subst(A,C,D), ring_subst_4(A,E).', 'great(A,B) :-   r_subst_1(A,C), ring_subst_2(B,D).', 'great(A,B) :-   ring_subst_4(B,C), n_val(A,D).', 'great(A,B) :-   x_subst(A,C,D), ring_subst_3(B,D).', 'great(A,B) :-   r_subst_1(A,C), n_val(B,D).', 'great(A,B) :-   ring_substitutions(B,C), ring_subst_5(A,D).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 17               | 6                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 43               | 67               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.632 |
# +-------------+-------+
# | Precision   | 0.739 |
# +-------------+-------+
# | Sensitivity | 0.283 |
# +-------------+-------+
# | Specificity | 0.918 |
# +-------------+-------+
# | F1 Score    | 0.410 |
# +-------------+-------+
# ['great(A,B) :-   r_subst_1(A,C), ring_subst_3(B,D).', 'great(A,B) :-   x_subst(A,C,D), ring_subst_4(A,E).', 'great(A,B) :-   r_subst_1(A,C), ring_subst_2(B,D).', 'great(A,B) :-   ring_subst_4(B,C), n_val(A,D).', 'great(A,B) :-   r_subst_1(A,C), n_val(B,D).', 'great(A,B) :-   ring_substitutions(B,C), ring_subst_5(A,D).', 'great(A,B) :-   x_subst(A,C,D), ring_subst_4(B,D).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 11               | 8                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 49               | 65               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.571 |
# +-------------+-------+
# | Precision   | 0.579 |
# +-------------+-------+
# | Sensitivity | 0.183 |
# +-------------+-------+
# | Specificity | 0.890 |
# +-------------+-------+
# | F1 Score    | 0.278 |
# +-------------+-------+
# ['great(A,B) :-   x_subst(A,C,D), ring_subst_4(A,E).', 'great(A,B) :-   r_subst_1(A,C), ring_subst_2(B,D).', 'great(A,B) :-   ring_subst_4(B,C), n_val(A,D).', 'great(A,B) :-   ring_substitutions(B,C), ring_subst_5(A,D).', 'great(A,B) :-   x_subst(A,C,D), ring_subst_4(B,D).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 23               | 4                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 37               | 69               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.692 |
# +-------------+-------+
# | Precision   | 0.852 |
# +-------------+-------+
# | Sensitivity | 0.383 |
# +-------------+-------+
# | Specificity | 0.945 |
# +-------------+-------+
# | F1 Score    | 0.529 |
# +-------------+-------+
# ['great(A,B) :-   r_subst_1(A,C), ring_subst_3(B,D).', 'great(A,B) :-   x_subst(A,C,D), ring_subst_4(A,E).', 'great(A,B) :-   r_subst_1(A,C), ring_subst_2(B,D).', 'great(A,B) :-   ring_subst_2(A,C), ring_subst_4(B,C).', 'great(A,B) :-   ring_subst_4(B,C), n_val(A,D).', 'great(A,B) :-   ring_substitutions(B,C), ring_subst_5(A,D).', 'great(A,B) :-   x_subst(A,C,D), ring_subst_4(B,D).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 132       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 20               | 10               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 39               | 63               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.629 |
# +-------------+-------+
# | Precision   | 0.667 |
# +-------------+-------+
# | Sensitivity | 0.339 |
# +-------------+-------+
# | Specificity | 0.863 |
# +-------------+-------+
# | F1 Score    | 0.449 |
# +-------------+-------+
# ['great(A,B) :-   r_subst_1(A,C), ring_subst_3(B,D).', 'great(A,B) :-   x_subst(A,C,D), ring_subst_4(A,E).', 'great(A,B) :-   r_subst_1(A,C), ring_subst_2(B,D).', 'great(A,B) :-   r_subst_1(A,C), ring_subst_4(B,D).', 'great(A,B) :-   r_subst_1(A,C), n_val(B,D).', 'great(A,B) :-   ring_substitutions(B,C), ring_subst_5(A,D).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 132       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 16               | 6                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 43               | 67               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.629 |
# +-------------+-------+
# | Precision   | 0.727 |
# +-------------+-------+
# | Sensitivity | 0.271 |
# +-------------+-------+
# | Specificity | 0.918 |
# +-------------+-------+
# | F1 Score    | 0.395 |
# +-------------+-------+
# ['great(A,B) :-   x_subst(A,C,D), ring_subst_4(A,E).', 'great(A,B) :-   r_subst_1(A,C), ring_subst_2(B,D).', 'great(A,B) :-   ring_subst_4(B,C), n_val(A,D).', 'great(A,B) :-   r_subst_1(A,C), n_val(B,D).', 'great(A,B) :-   ring_substitutions(B,C), ring_subst_5(A,D).', 'great(A,B) :-   x_subst(A,C,D), ring_subst_4(B,D).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 131       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 20               | 7                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 39               | 65               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.649 |
# +-------------+-------+
# | Precision   | 0.741 |
# +-------------+-------+
# | Sensitivity | 0.339 |
# +-------------+-------+
# | Specificity | 0.903 |
# +-------------+-------+
# | F1 Score    | 0.465 |
# +-------------+-------+

# %% [markdown]
# # System 2 - Metagol_NT

# %%
tic= time.time()
model_metagol=metagolnt_cross_validation(file="BK_metagol.pl", positive_example="pos_example.f", 
                                         negative_example="neg_example.n", CV=10,  shuffle=True,
                                         num_pos=2, num_neg=2, max_run=30)
print(time.time()-tic)
# Out:
# (['great(A,B):-alk_groups(B,4),alk_groups(A,1)', 'great(A,B):-alk_groups(B,1),alk_groups(A,0)'], 0.641)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 16               | 4                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 44               | 69               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.639 |
# +-------------+-------+
# | Precision   | 0.800 |
# +-------------+-------+
# | Sensitivity | 0.267 |
# +-------------+-------+
# | Specificity | 0.945 |
# +-------------+-------+
# | F1 Score    | 0.400 |
# +-------------+-------+
# (['great(A,B):-alk_groups(B,1),alk_groups(A,0)', 'great(A,B):-alk_groups(B,4),alk_groups(A,1)'], 0.641)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 19               | 7                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 41               | 66               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.639 |
# +-------------+-------+
# | Precision   | 0.731 |
# +-------------+-------+
# | Sensitivity | 0.317 |
# +-------------+-------+
# | Specificity | 0.904 |
# +-------------+-------+
# | F1 Score    | 0.442 |
# +-------------+-------+
# (['great(A,B):-alk_groups(B,1),alk_groups(A,0)', 'great(A,B):-alk_groups(B,4),alk_groups(A,1)'], 0.64)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 19               | 6                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 41               | 67               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.647 |
# +-------------+-------+
# | Precision   | 0.760 |
# +-------------+-------+
# | Sensitivity | 0.317 |
# +-------------+-------+
# | Specificity | 0.918 |
# +-------------+-------+
# | F1 Score    | 0.447 |
# +-------------+-------+
# (['great(A,B):-alk_groups(B,1),alk_groups(A,0)', 'great(A,B):-alk_groups(B,4),alk_groups(A,1)'], 0.642)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 16               | 5                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 44               | 68               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.632 |
# +-------------+-------+
# | Precision   | 0.762 |
# +-------------+-------+
# | Sensitivity | 0.267 |
# +-------------+-------+
# | Specificity | 0.932 |
# +-------------+-------+
# | F1 Score    | 0.395 |
# +-------------+-------+
# (['great(A,B):-alk_groups(B,1),alk_groups(A,0)', 'great(A,B):-alk_groups(B,4),alk_groups(A,1)'], 0.642)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 19               | 8                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 41               | 65               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.632 |
# +-------------+-------+
# | Precision   | 0.704 |
# +-------------+-------+
# | Sensitivity | 0.317 |
# +-------------+-------+
# | Specificity | 0.890 |
# +-------------+-------+
# | F1 Score    | 0.437 |
# +-------------+-------+
# (['great(A,B):-alk_groups(B,1),alk_groups(A,0)', 'great(A,B):-alk_groups(B,4),alk_groups(A,1)'], 0.645)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 15               | 8                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 45               | 65               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.602 |
# +-------------+-------+
# | Precision   | 0.652 |
# +-------------+-------+
# | Sensitivity | 0.250 |
# +-------------+-------+
# | Specificity | 0.890 |
# +-------------+-------+
# | F1 Score    | 0.361 |
# +-------------+-------+
# (['great(A,B):-alk_groups(B,4),alk_groups(A,1)', 'great(A,B):-alk_groups(B,1),alk_groups(A,0)'], 0.643)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 133       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 15               | 5                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 45               | 68               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.624 |
# +-------------+-------+
# | Precision   | 0.750 |
# +-------------+-------+
# | Sensitivity | 0.250 |
# +-------------+-------+
# | Specificity | 0.932 |
# +-------------+-------+
# | F1 Score    | 0.375 |
# +-------------+-------+
# (['great(A,B):-alk_groups(B,1),alk_groups(A,0)', 'great(A,B):-alk_groups(B,4),alk_groups(A,1)'], 0.639)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 132       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 18               | 5                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 41               | 68               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.652 |
# +-------------+-------+
# | Precision   | 0.783 |
# +-------------+-------+
# | Sensitivity | 0.305 |
# +-------------+-------+
# | Specificity | 0.932 |
# +-------------+-------+
# | F1 Score    | 0.439 |
# +-------------+-------+
# (['great(A,B):-alk_groups(B,4),alk_groups(A,1)', 'great(A,B):-alk_groups(B,1),alk_groups(A,0)'], 0.635)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 132       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 23               | 5                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 36               | 68               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.689 |
# +-------------+-------+
# | Precision   | 0.821 |
# +-------------+-------+
# | Sensitivity | 0.390 |
# +-------------+-------+
# | Specificity | 0.932 |
# +-------------+-------+
# | F1 Score    | 0.529 |
# +-------------+-------+
# (['great(A,B):-alk_groups(B,1),alk_groups(A,0)', 'great(A,B):-alk_groups(B,4),alk_groups(A,0)'], 0.616)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 131       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 12               | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 47               | 71               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.634 |
# +-------------+-------+
# | Precision   | 0.923 |
# +-------------+-------+
# | Sensitivity | 0.203 |
# +-------------+-------+
# | Specificity | 0.986 |
# +-------------+-------+
# | F1 Score    | 0.333 |
# +-------------+-------+
# 15.807646036148071

# %% [markdown]
# # System 3 - PyGol

# %%
constant_1=[]
P, N = bottom_clause_generation(file="BK.pl",constant_set = constant_1,   container = "dict", depth=2, 
                                positive_example="pos_example.f", negative_example="neg_example.n")
folds=pygol_folds(folds=10, shuffle=True)
model_pygol=pygol_cross_validation(folds, file="BK.pl", k_fold=10, min_pos=2, constant_set=constant_1,
                             key_size=10,  max_literals=2, max_neg=30)
# Out:
# 100%|██████████| 597/597 [00:00<00:00, 670.89it/s]
# 100%|██████████| 729/729 [00:01<00:00, 673.79it/s]
# 100%|██████████| 537/537 [00:05<00:00, 102.29it/s]
# 100%|██████████| 656/656 [00:06<00:00, 103.76it/s]
# +----------+ Hypothesis +----------+
# ['great(A,B):-alk_groups(A,0),ring_substitutions(B,1)', 'great(A,B):-ring_substitutions(A,0),x_subst(B,7,C)', 'great(A,B):-ring_substitutions(B,5),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,5)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,0)', 'great(A,B):-alk_groups(A,3),x_subst(B,7,C)', 'great(A,B):-alk_groups(A,2),x_subst(B,7,C)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,D)', 'great(A,B):-alk_groups(B,3),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,0),x_subst(B,7,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,7,C)', 'great(A,B):-alk_groups(A,3),ring_subst_4(B,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,1),ring_substitutions(A,5)', 'great(A,B):-alk_groups(B,2),r_subst_1(A,C)', 'great(A,B):-ring_subst_4(B,C),x_subst(A,6,D)', 'great(A,B):-alk_groups(A,3),ring_subst_2(B,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,5)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,C)', 'great(A,B):-alk_groups(B,4),ring_substitutions(A,0)', 'great(A,B):-alk_groups(A,3),ring_subst_3(B,C)', 'great(A,B):-alk_groups(A,1),x_subst(B,7,C)', 'great(A,B):-alk_groups(A,2),ring_subst_4(B,C)', 'great(A,B):-alk_groups(A,2),ring_subst_3(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_3(A,C)', 'great(A,B):-alk_groups(A,2),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_4(A,C)', 'great(A,B):-ring_substitutions(B,0),x_subst(A,6,C)', 'great(A,B):-alk_groups(B,4),ring_subst_2(A,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,6,C)', 'great(A,B):-alk_groups(B,4),r_subst_1(A,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,0)']
# +---------------------+------------------+------------------+
# |      n = 1193       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 333              | 129              |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 204              | 527              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.721 |
# +-------------+-------+
# | Precision   | 0.721 |
# +-------------+-------+
# | Sensitivity | 0.620 |
# +-------------+-------+
# | Specificity | 0.803 |
# +-------------+-------+
# | F1 Score    | 0.667 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 132       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 40               | 17               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 20               | 55               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.720 |
# +-------------+-------+
# | Precision   | 0.702 |
# +-------------+-------+
# | Sensitivity | 0.667 |
# +-------------+-------+
# | Specificity | 0.764 |
# +-------------+-------+
# | F1 Score    | 0.684 |
# +-------------+-------+
# 100%|██████████| 537/537 [00:00<00:00, 928.38it/s]
# 100%|██████████| 656/656 [00:00<00:00, 900.92it/s]
# +----------+ Hypothesis +----------+
# ['great(A,B):-alk_groups(A,0),ring_substitutions(B,1)', 'great(A,B):-ring_substitutions(A,5),ring_subst_4(B,C)', 'great(A,B):-ring_substitutions(A,0),x_subst(B,7,C)', 'great(A,B):-ring_substitutions(B,5),x_subst(A,6,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_2(B,C)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,D)', 'great(A,B):-alk_groups(A,2),x_subst(B,7,C)', 'great(A,B):-alk_groups(A,3),x_subst(B,7,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,7,C)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,5)', 'great(A,B):-alk_groups(A,3),ring_subst_4(B,C)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,0)', 'great(A,B):-alk_groups(B,3),r_subst_1(A,C)', 'great(A,B):-ring_subst_4(B,C),x_subst(A,6,D)', 'great(A,B):-ring_substitutions(A,5),ring_subst_3(B,C)', 'great(A,B):-alk_groups(B,2),x_subst(A,6,C)', 'great(A,B):-r_subst_1(A,C),x_subst(B,7,D)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,5)', 'great(A,B):-ring_substitutions(A,0),ring_subst_2(B,C)', 'great(A,B):-alk_groups(A,3),ring_subst_3(B,C)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,C)', 'great(A,B):-alk_groups(B,4),ring_substitutions(A,0)', 'great(A,B):-alk_groups(A,1),x_subst(B,7,C)', 'great(A,B):-ring_substitutions(B,0),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,2),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_3(A,C)', 'great(A,B):-alk_groups(A,2),ring_subst_4(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_4(A,C)', 'great(A,B):-alk_groups(A,2),ring_subst_3(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_2(A,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,0)']
# +---------------------+------------------+------------------+
# |      n = 1193       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 339              | 134              |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 198              | 522              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.722 |
# +-------------+-------+
# | Precision   | 0.717 |
# +-------------+-------+
# | Sensitivity | 0.631 |
# +-------------+-------+
# | Specificity | 0.796 |
# +-------------+-------+
# | F1 Score    | 0.671 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 132       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 33               | 17               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 27               | 55               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.667 |
# +-------------+-------+
# | Precision   | 0.660 |
# +-------------+-------+
# | Sensitivity | 0.550 |
# +-------------+-------+
# | Specificity | 0.764 |
# +-------------+-------+
# | F1 Score    | 0.600 |
# +-------------+-------+
# 100%|██████████| 537/537 [00:00<00:00, 1143901.09it/s]
# 100%|██████████| 656/656 [00:00<00:00, 1918733.21it/s]
# +----------+ Hypothesis +----------+
# ['great(A,B):-alk_groups(A,0),ring_substitutions(B,1)', 'great(A,B):-ring_substitutions(B,5),x_subst(A,6,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_2(B,C)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,D)', 'great(A,B):-alk_groups(A,3),x_subst(B,7,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_4(B,C)', 'great(A,B):-alk_groups(A,2),x_subst(B,7,C)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,5)', 'great(A,B):-alk_groups(B,4),x_subst(A,7,C)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,0)', 'great(A,B):-alk_groups(B,3),x_subst(A,6,C)', 'great(A,B):-ring_subst_4(B,C),x_subst(A,6,D)', 'great(A,B):-ring_substitutions(A,0),ring_subst_3(B,C)', 'great(A,B):-alk_groups(B,2),r_subst_1(A,C)', 'great(A,B):-r_subst_1(A,C),x_subst(B,7,D)', 'great(A,B):-ring_substitutions(A,0),ring_subst_2(B,C)', 'great(A,B):-alk_groups(A,3),ring_subst_4(B,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_3(B,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,5)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,3),ring_subst_2(B,C)', 'great(A,B):-ring_substitutions(B,0),x_subst(A,6,C)', 'great(A,B):-alk_groups(B,4),ring_substitutions(A,0)', 'great(A,B):-alk_groups(A,1),x_subst(B,7,C)', 'great(A,B):-alk_groups(B,4),ring_subst_3(A,C)', 'great(A,B):-alk_groups(A,2),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_4(A,C)', 'great(A,B):-alk_groups(A,2),ring_subst_4(B,C)', 'great(A,B):-alk_groups(A,2),ring_subst_3(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_2(A,C)', 'great(A,B):-alk_groups(B,4),r_subst_1(A,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,0)']
# +---------------------+------------------+------------------+
# |      n = 1193       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 341              | 149              |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 196              | 507              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.711 |
# +-------------+-------+
# | Precision   | 0.696 |
# +-------------+-------+
# | Sensitivity | 0.635 |
# +-------------+-------+
# | Specificity | 0.773 |
# +-------------+-------+
# | F1 Score    | 0.664 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 132       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 38               | 18               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 22               | 54               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.697 |
# +-------------+-------+
# | Precision   | 0.679 |
# +-------------+-------+
# | Sensitivity | 0.633 |
# +-------------+-------+
# | Specificity | 0.750 |
# +-------------+-------+
# | F1 Score    | 0.655 |
# +-------------+-------+
# 100%|██████████| 537/537 [00:00<00:00, 1615739.78it/s]
# 100%|██████████| 656/656 [00:00<00:00, 970533.84it/s]
# +----------+ Hypothesis +----------+
# ['great(A,B):-alk_groups(A,0),ring_substitutions(B,1)', 'great(A,B):-ring_substitutions(A,0),x_subst(B,7,C)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,0)', 'great(A,B):-ring_substitutions(A,5),ring_subst_4(B,C)', 'great(A,B):-ring_substitutions(B,5),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,3),x_subst(B,7,C)', 'great(A,B):-alk_groups(A,2),x_subst(B,7,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,7,C)', 'great(A,B):-ring_subst_4(B,C),x_subst(A,6,D)', 'great(A,B):-r_subst_1(A,C),x_subst(B,7,D)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,5)', 'great(A,B):-alk_groups(B,3),x_subst(A,6,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_3(B,C)', 'great(A,B):-ring_substitutions(A,0),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,2),r_subst_1(A,C)', 'great(A,B):-ring_substitutions(A,0),ring_subst_3(B,C)', 'great(A,B):-alk_groups(A,3),ring_subst_4(B,C)', 'great(A,B):-alk_groups(B,4),ring_substitutions(A,0)', 'great(A,B):-alk_groups(A,3),ring_subst_2(B,C)', 'great(A,B):-alk_groups(A,1),x_subst(B,7,C)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,2),ring_subst_4(B,C)', 'great(A,B):-alk_groups(A,3),ring_subst_3(B,C)', 'great(A,B):-alk_groups(A,2),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_3(A,C)', 'great(A,B):-ring_substitutions(B,0),x_subst(A,6,C)', 'great(A,B):-alk_groups(B,4),ring_subst_4(A,C)', 'great(A,B):-alk_groups(A,2),ring_subst_3(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_2(A,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,6,C)', 'great(A,B):-alk_groups(B,4),r_subst_1(A,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,0)']
# +---------------------+------------------+------------------+
# |      n = 1193       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 334              | 145              |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 203              | 511              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.708 |
# +-------------+-------+
# | Precision   | 0.697 |
# +-------------+-------+
# | Sensitivity | 0.622 |
# +-------------+-------+
# | Specificity | 0.779 |
# +-------------+-------+
# | F1 Score    | 0.657 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 132       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 42               | 18               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 18               | 54               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.727 |
# +-------------+-------+
# | Precision   | 0.700 |
# +-------------+-------+
# | Sensitivity | 0.700 |
# +-------------+-------+
# | Specificity | 0.750 |
# +-------------+-------+
# | F1 Score    | 0.700 |
# +-------------+-------+
# 100%|██████████| 537/537 [00:00<00:00, 1936664.87it/s]
# 100%|██████████| 656/656 [00:00<00:00, 2070326.13it/s]
# +----------+ Hypothesis +----------+
# ['great(A,B):-alk_groups(A,0),ring_substitutions(B,1)', 'great(A,B):-ring_substitutions(A,5),ring_subst_4(B,C)', 'great(A,B):-ring_substitutions(B,5),x_subst(A,6,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_2(B,C)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,5)', 'great(A,B):-alk_groups(A,2),x_subst(B,7,C)', 'great(A,B):-ring_subst_4(B,C),x_subst(A,6,D)', 'great(A,B):-alk_groups(A,3),x_subst(B,7,C)', 'great(A,B):-ring_substitutions(A,0),x_subst(B,7,C)', 'great(A,B):-alk_groups(B,3),x_subst(A,6,C)', 'great(A,B):-alk_groups(B,2),r_subst_1(A,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,7,C)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,D)', 'great(A,B):-alk_groups(A,3),ring_subst_4(B,C)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,0)', 'great(A,B):-r_subst_1(A,C),x_subst(B,7,D)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,5)', 'great(A,B):-ring_substitutions(A,5),ring_subst_3(B,C)', 'great(A,B):-alk_groups(A,3),ring_subst_3(B,C)', 'great(A,B):-alk_groups(B,4),ring_substitutions(A,0)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,3),ring_subst_2(B,C)', 'great(A,B):-alk_groups(A,2),ring_subst_2(B,C)', 'great(A,B):-ring_substitutions(B,0),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,1),x_subst(B,7,C)', 'great(A,B):-alk_groups(B,4),ring_subst_3(A,C)', 'great(A,B):-alk_groups(B,4),ring_subst_2(A,C)', 'great(A,B):-alk_groups(A,2),ring_subst_4(B,C)', 'great(A,B):-alk_groups(A,2),ring_subst_3(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_4(A,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,6,C)', 'great(A,B):-alk_groups(B,4),r_subst_1(A,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,0)']
# +---------------------+------------------+------------------+
# |      n = 1193       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 338              | 126              |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 199              | 530              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.728 |
# +-------------+-------+
# | Precision   | 0.728 |
# +-------------+-------+
# | Sensitivity | 0.629 |
# +-------------+-------+
# | Specificity | 0.808 |
# +-------------+-------+
# | F1 Score    | 0.675 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 132       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 33               | 16               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 27               | 56               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.674 |
# +-------------+-------+
# | Precision   | 0.673 |
# +-------------+-------+
# | Sensitivity | 0.550 |
# +-------------+-------+
# | Specificity | 0.778 |
# +-------------+-------+
# | F1 Score    | 0.606 |
# +-------------+-------+
# 100%|██████████| 537/537 [00:00<00:00, 1866065.66it/s]
# 100%|██████████| 656/656 [00:00<00:00, 1976626.02it/s]
# +----------+ Hypothesis +----------+
# ['great(A,B):-alk_groups(A,0),ring_substitutions(B,1)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,D)', 'great(A,B):-ring_substitutions(B,5),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,2),x_subst(B,7,C)', 'great(A,B):-alk_groups(A,3),x_subst(B,7,C)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,5)', 'great(A,B):-ring_substitutions(A,5),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,3),x_subst(A,6,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_4(B,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,7,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_3(B,C)', 'great(A,B):-r_subst_1(A,C),x_subst(B,7,D)', 'great(A,B):-ring_subst_4(B,C),x_subst(A,6,D)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,0)', 'great(A,B):-alk_groups(B,2),r_subst_1(A,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,5)', 'great(A,B):-ring_substitutions(A,0),ring_subst_3(B,C)', 'great(A,B):-alk_groups(A,3),ring_subst_4(B,C)', 'great(A,B):-alk_groups(B,4),ring_substitutions(A,0)', 'great(A,B):-alk_groups(A,1),x_subst(B,7,C)', 'great(A,B):-alk_groups(A,3),ring_subst_3(B,C)', 'great(A,B):-alk_groups(A,2),ring_subst_2(B,C)', 'great(A,B):-alk_groups(A,3),ring_subst_2(B,C)', 'great(A,B):-ring_substitutions(B,0),x_subst(A,6,C)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,C)', 'great(A,B):-alk_groups(B,4),ring_subst_4(A,C)', 'great(A,B):-alk_groups(B,4),ring_subst_2(A,C)', 'great(A,B):-alk_groups(B,4),ring_subst_3(A,C)', 'great(A,B):-alk_groups(A,2),ring_subst_4(B,C)', 'great(A,B):-alk_groups(A,2),ring_subst_3(B,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,0)']
# +---------------------+------------------+------------------+
# |      n = 1193       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 338              | 139              |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 199              | 517              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.717 |
# +-------------+-------+
# | Precision   | 0.709 |
# +-------------+-------+
# | Sensitivity | 0.629 |
# +-------------+-------+
# | Specificity | 0.788 |
# +-------------+-------+
# | F1 Score    | 0.667 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 132       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 42               | 18               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 18               | 54               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.727 |
# +-------------+-------+
# | Precision   | 0.700 |
# +-------------+-------+
# | Sensitivity | 0.700 |
# +-------------+-------+
# | Specificity | 0.750 |
# +-------------+-------+
# | F1 Score    | 0.700 |
# +-------------+-------+
# 100%|██████████| 537/537 [00:00<00:00, 1715416.03it/s]
# 100%|██████████| 656/656 [00:00<00:00, 1652530.58it/s]
# +----------+ Hypothesis +----------+
# ['great(A,B):-alk_groups(A,0),ring_substitutions(B,1)', 'great(A,B):-ring_substitutions(A,0),x_subst(B,7,C)', 'great(A,B):-ring_subst_4(B,C),x_subst(A,6,D)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,0)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,5)', 'great(A,B):-ring_substitutions(A,5),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,2),r_subst_1(A,C)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,D)', 'great(A,B):-alk_groups(B,4),x_subst(A,7,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_3(B,C)', 'great(A,B):-alk_groups(A,3),ring_subst_4(B,C)', 'great(A,B):-alk_groups(A,0),x_subst(B,7,C)', 'great(A,B):-alk_groups(B,3),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,5)', 'great(A,B):-ring_substitutions(A,0),ring_subst_2(B,C)', 'great(A,B):-alk_groups(A,1),x_subst(B,7,C)', 'great(A,B):-ring_substitutions(A,0),ring_subst_3(B,C)', 'great(A,B):-alk_groups(A,3),ring_subst_3(B,C)', 'great(A,B):-alk_groups(B,4),ring_substitutions(A,0)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,C)', 'great(A,B):-ring_substitutions(B,0),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,2),ring_subst_2(B,C)', 'great(A,B):-alk_groups(A,2),ring_subst_4(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_4(A,C)', 'great(A,B):-alk_groups(A,2),ring_subst_3(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_3(A,C)', 'great(A,B):-alk_groups(B,4),ring_subst_2(A,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,0)']
# +---------------------+------------------+------------------+
# |      n = 1193       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 339              | 145              |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 198              | 511              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.712 |
# +-------------+-------+
# | Precision   | 0.700 |
# +-------------+-------+
# | Sensitivity | 0.631 |
# +-------------+-------+
# | Specificity | 0.779 |
# +-------------+-------+
# | F1 Score    | 0.664 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 132       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 35               | 17               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 25               | 55               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.682 |
# +-------------+-------+
# | Precision   | 0.673 |
# +-------------+-------+
# | Sensitivity | 0.583 |
# +-------------+-------+
# | Specificity | 0.764 |
# +-------------+-------+
# | F1 Score    | 0.625 |
# +-------------+-------+
# 100%|██████████| 538/538 [00:00<00:00, 1683981.76it/s]
# 100%|██████████| 656/656 [00:00<00:00, 1079852.21it/s]
# +----------+ Hypothesis +----------+
# ['great(A,B):-alk_groups(A,0),ring_substitutions(B,1)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,D)', 'great(A,B):-ring_substitutions(A,5),ring_subst_4(B,C)', 'great(A,B):-ring_substitutions(A,0),x_subst(B,7,C)', 'great(A,B):-alk_groups(B,2),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,5)', 'great(A,B):-alk_groups(A,3),x_subst(B,7,C)', 'great(A,B):-ring_subst_4(B,C),x_subst(A,6,D)', 'great(A,B):-ring_substitutions(A,5),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,7,C)', 'great(A,B):-r_subst_1(A,C),x_subst(B,7,D)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,0)', 'great(A,B):-ring_substitutions(A,5),ring_subst_3(B,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,5)', 'great(A,B):-alk_groups(A,3),ring_subst_4(B,C)', 'great(A,B):-alk_groups(B,3),r_subst_1(A,C)', 'great(A,B):-alk_groups(A,3),ring_subst_3(B,C)', 'great(A,B):-ring_substitutions(A,0),ring_subst_2(B,C)', 'great(A,B):-ring_substitutions(B,0),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,3),ring_subst_2(B,C)', 'great(A,B):-alk_groups(A,2),ring_subst_2(B,C)', 'great(A,B):-alk_groups(A,1),x_subst(B,7,C)', 'great(A,B):-alk_groups(B,4),ring_substitutions(A,0)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,2),ring_subst_4(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_3(A,C)', 'great(A,B):-alk_groups(B,4),ring_subst_4(A,C)', 'great(A,B):-alk_groups(A,2),ring_subst_3(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_2(A,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,0)']
# +---------------------+------------------+------------------+
# |      n = 1194       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 341              | 127              |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 197              | 529              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.729 |
# +-------------+-------+
# | Precision   | 0.729 |
# +-------------+-------+
# | Sensitivity | 0.634 |
# +-------------+-------+
# | Specificity | 0.806 |
# +-------------+-------+
# | F1 Score    | 0.678 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 131       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 33               | 17               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 26               | 55               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.672 |
# +-------------+-------+
# | Precision   | 0.660 |
# +-------------+-------+
# | Sensitivity | 0.559 |
# +-------------+-------+
# | Specificity | 0.764 |
# +-------------+-------+
# | F1 Score    | 0.606 |
# +-------------+-------+
# 100%|██████████| 538/538 [00:00<00:00, 1196466.36it/s]
# 100%|██████████| 656/656 [00:00<00:00, 1119846.73it/s]
# +----------+ Hypothesis +----------+
# ['great(A,B):-alk_groups(A,0),ring_substitutions(B,1)', 'great(A,B):-ring_subst_4(B,C),x_subst(A,6,D)', 'great(A,B):-ring_substitutions(A,0),x_subst(B,7,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,1),ring_substitutions(A,5)', 'great(A,B):-alk_groups(A,2),x_subst(B,7,C)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,5)', 'great(A,B):-alk_groups(A,3),x_subst(B,7,C)', 'great(A,B):-alk_groups(A,3),ring_subst_4(B,C)', 'great(A,B):-r_subst_1(A,C),x_subst(B,7,D)', 'great(A,B):-ring_substitutions(A,0),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,3),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,0)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,5)', 'great(A,B):-alk_groups(B,2),r_subst_1(A,C)', 'great(A,B):-ring_substitutions(B,0),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,3),ring_subst_3(B,C)', 'great(A,B):-alk_groups(A,3),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,4),ring_substitutions(A,0)', 'great(A,B):-alk_groups(A,2),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_3(A,C)', 'great(A,B):-alk_groups(A,1),x_subst(B,7,C)', 'great(A,B):-alk_groups(A,2),ring_subst_3(B,C)', 'great(A,B):-alk_groups(A,2),ring_subst_4(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_4(A,C)', 'great(A,B):-alk_groups(B,4),ring_subst_2(A,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,0)']
# +---------------------+------------------+------------------+
# |      n = 1194       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 328              | 140              |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 210              | 516              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.707 |
# +-------------+-------+
# | Precision   | 0.701 |
# +-------------+-------+
# | Sensitivity | 0.610 |
# +-------------+-------+
# | Specificity | 0.787 |
# +-------------+-------+
# | F1 Score    | 0.652 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 131       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 39               | 18               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 20               | 54               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.710 |
# +-------------+-------+
# | Precision   | 0.684 |
# +-------------+-------+
# | Sensitivity | 0.661 |
# +-------------+-------+
# | Specificity | 0.750 |
# +-------------+-------+
# | F1 Score    | 0.672 |
# +-------------+-------+
# 100%|██████████| 538/538 [00:00<00:00, 1885159.19it/s]
# 100%|██████████| 657/657 [00:00<00:00, 1864450.42it/s]
# +----------+ Hypothesis +----------+
# ['great(A,B):-alk_groups(A,0),ring_substitutions(B,1)', 'great(A,B):-ring_substitutions(A,5),x_subst(B,6,C)', 'great(A,B):-ring_substitutions(A,0),x_subst(B,7,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_4(B,C)', 'great(A,B):-ring_substitutions(B,5),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,3),ring_subst_4(B,C)', 'great(A,B):-alk_groups(A,2),x_subst(B,7,C)', 'great(A,B):-alk_groups(A,3),x_subst(B,7,C)', 'great(A,B):-ring_substitutions(A,5),ring_subst_2(B,C)', 'great(A,B):-ring_substitutions(A,0),ring_subst_3(B,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,7,C)', 'great(A,B):-alk_groups(B,2),r_subst_1(A,C)', 'great(A,B):-ring_subst_4(B,C),x_subst(A,6,D)', 'great(A,B):-r_subst_1(A,C),x_subst(B,7,D)', 'great(A,B):-alk_groups(A,2),ring_substitutions(B,0)', 'great(A,B):-ring_substitutions(A,5),ring_subst_3(B,C)', 'great(A,B):-ring_substitutions(A,0),ring_subst_2(B,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,5)', 'great(A,B):-alk_groups(B,3),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,3),ring_subst_2(B,C)', 'great(A,B):-ring_subst_2(B,C),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,1),x_subst(B,7,C)', 'great(A,B):-alk_groups(B,4),ring_substitutions(A,0)', 'great(A,B):-alk_groups(B,4),ring_subst_3(A,C)', 'great(A,B):-alk_groups(A,2),ring_subst_2(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_4(A,C)', 'great(A,B):-ring_substitutions(B,0),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,2),ring_subst_4(B,C)', 'great(A,B):-alk_groups(A,2),ring_subst_3(B,C)', 'great(A,B):-alk_groups(B,4),ring_subst_2(A,C)', 'great(A,B):-alk_groups(B,4),x_subst(A,6,C)', 'great(A,B):-alk_groups(A,0),ring_substitutions(B,0)']
# +---------------------+------------------+------------------+
# |      n = 1195       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 339              | 149              |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 199              | 508              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.709 |
# +-------------+-------+
# | Precision   | 0.695 |
# +-------------+-------+
# | Sensitivity | 0.630 |
# +-------------+-------+
# | Specificity | 0.773 |
# +-------------+-------+
# | F1 Score    | 0.661 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 132       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 35               | 14               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 24               | 59               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.712 |
# +-------------+-------+
# | Precision   | 0.714 |
# +-------------+-------+
# | Sensitivity | 0.593 |
# +-------------+-------+
# | Specificity | 0.808 |
# +-------------+-------+
# | F1 Score    | 0.648 |
# +-------------+-------+

# %% [markdown]
# # System 4 - Progolem

# %%
# %%sh
# cat run_script.sh
# ./run_script.sh
# Out:
# yap -l run.pl > output.txt
# % Restoring file /usr/lib/Yap/startup.yss
# YAP 6.2.2 (x86_64-linux): Sat Sep 17 13:59:03 UTC 2016

# %%
model_progolem = metric_progolem()

# %% [markdown]
# # Evaluation Metrics

# %%
d = {'Pygol': [round(np.mean(model_pygol.accuracy),2), round(np.std(model_pygol.accuracy),1), 
               round(model_pygol.time_learn,2)],
'Metagol_NT': [round(np.mean(model_metagol.accuracy),2), round(np.std(model_metagol.accuracy),2),  
               round(model_metagol.time_learn,2)],
'ProGolem': [round(model_progolem['accuracy'],2), round(model_progolem['error'],2),
             round(model_progolem['time'],2)],
'Aleph': [round(np.mean(model_aleph.accuracy),2), round(np.std(model_aleph.accuracy),2), 
          round(model_aleph.time_learn,2)]
}
print ("{:<15} {:<10} {:<10} {:<10}".format('System','Accuracy','Std. Dev','Time'))
print ("{:<15} {:<10} {:<10} {:<10}".format('------','--------','-----','----'))
for k, v in d.items():
    lang, perc, change = v
    print ("{:<15} {:<10} {:<10} {:<10}".format(k, lang, perc, change))
# Out:
# System          Accuracy   Std. Dev   Time
# ------          --------   -----      ----
# Pygol           0.7        0.0        13.99
# Metagol_NT      0.64       0.02       15.8
# ProGolem        54.4       3.3        26.3
# Aleph           0.63       0.03       79.5
