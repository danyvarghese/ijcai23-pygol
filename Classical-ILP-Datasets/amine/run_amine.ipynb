# %% [markdown]
# # Import Packages

# %%
from pygol import *
from  PyILP import *
from help_progolem import *

# %% [markdown]
# # Parameter Settings

# %%
"""
Clause Length = 3
Min. Pos      = 10
Max. Noise    = 10
Evl.Function  = coverage 
"""
# Out:
# '\nClause Length = 3\nMin. Pos      = 10\nMax. Noise    = 10\nEvl.Function  = coverage \n'

# %% [markdown]
# # System 1 - Aleph

# %%
model_aleph=aleph_cross_validation(file="BK.pl", settings="modes.pl",  CV=10, shuffle=True,  positive_example="pos_example.f", 
                                       negative_example="neg_example.n")
# Out:
# ['great_ne(A,B) :-   r_subst_2(A,C), ring_subst_5(B,D).', 'great_ne(A,B) :-   x_subst(B,C,D), ring_subst_4(B,E).', 'great_ne(A,B) :-   r_subst_3(B,C), ring_substitutions(A,D).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 4                | 2                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 27               | 36               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.580 |
# +-------------+-------+
# | Precision   | 0.667 |
# +-------------+-------+
# | Sensitivity | 0.129 |
# +-------------+-------+
# | Specificity | 0.947 |
# +-------------+-------+
# | F1 Score    | 0.216 |
# +-------------+-------+
# ['great_ne(A,B) :-   x_subst(A,C,D), ring_subst_2(A,E).', 'great_ne(A,B) :-   ring_subst_3(A,C), ring_subst_4(B,D).', 'great_ne(A,B) :-   ring_subst_2(A,C), ring_subst_3(B,D).', 'great_ne(A,B) :-   r_subst_3(B,C), ring_substitutions(A,D).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 9                | 6                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 22               | 32               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.594 |
# +-------------+-------+
# | Precision   | 0.600 |
# +-------------+-------+
# | Sensitivity | 0.290 |
# +-------------+-------+
# | Specificity | 0.842 |
# +-------------+-------+
# | F1 Score    | 0.391 |
# +-------------+-------+
# ['great_ne(A,B) :-   ring_subst_3(A,C), ring_subst_4(B,D).', 'great_ne(A,B) :-   ring_subst_2(A,C), ring_subst_3(B,D).', 'great_ne(A,B) :-   r_subst_3(B,C), ring_substitutions(A,D).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 10               | 4                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 21               | 34               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.638 |
# +-------------+-------+
# | Precision   | 0.714 |
# +-------------+-------+
# | Sensitivity | 0.323 |
# +-------------+-------+
# | Specificity | 0.895 |
# +-------------+-------+
# | F1 Score    | 0.444 |
# +-------------+-------+
# ['great_ne(A,B) :-   x_subst(A,C,D), ring_subst_2(A,E).', 'great_ne(A,B) :-   ring_subst_3(A,C), ring_subst_4(B,D).', 'great_ne(A,B) :-   ring_subst_2(A,C), ring_subst_3(B,D).', 'great_ne(A,B) :-   r_subst_3(B,C), ring_substitutions(A,D).', 'great_ne(A,B) :-   ring_subst_5(B,C).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 8                | 4                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 23               | 34               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.609 |
# +-------------+-------+
# | Precision   | 0.667 |
# +-------------+-------+
# | Sensitivity | 0.258 |
# +-------------+-------+
# | Specificity | 0.895 |
# +-------------+-------+
# | F1 Score    | 0.372 |
# +-------------+-------+
# ['great_ne(A,B) :-   x_subst(A,C,D), ring_subst_2(A,E).', 'great_ne(A,B) :-   ring_subst_3(A,C), ring_subst_4(B,D).', 'great_ne(A,B) :-   ring_subst_2(A,C), ring_subst_3(B,D).', 'great_ne(A,B) :-   ring_subst_5(B,C).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 13               | 6                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 18               | 32               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.652 |
# +-------------+-------+
# | Precision   | 0.684 |
# +-------------+-------+
# | Sensitivity | 0.419 |
# +-------------+-------+
# | Specificity | 0.842 |
# +-------------+-------+
# | F1 Score    | 0.520 |
# +-------------+-------+
# ['great_ne(A,B) :-   x_subst(B,C,D), ring_subst_4(B,E).', 'great_ne(A,B) :-   ring_subst_3(A,C), ring_subst_4(B,D).', 'great_ne(A,B) :-   r_subst_3(B,C), ring_substitutions(A,D).', 'great_ne(A,B) :-   ring_subst_5(B,C).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 8                | 5                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 23               | 33               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.594 |
# +-------------+-------+
# | Precision   | 0.615 |
# +-------------+-------+
# | Sensitivity | 0.258 |
# +-------------+-------+
# | Specificity | 0.868 |
# +-------------+-------+
# | F1 Score    | 0.364 |
# +-------------+-------+
# ['great_ne(A,B) :-   ring_subst_3(A,C), ring_subst_4(B,D).', 'great_ne(A,B) :-   ring_subst_2(A,C), ring_subst_3(B,D).', 'great_ne(A,B) :-   r_subst_3(B,C), ring_substitutions(A,D).', 'great_ne(A,B) :-   ring_subst_5(B,C).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 5                | 2                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 26               | 36               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.594 |
# +-------------+-------+
# | Precision   | 0.714 |
# +-------------+-------+
# | Sensitivity | 0.161 |
# +-------------+-------+
# | Specificity | 0.947 |
# +-------------+-------+
# | F1 Score    | 0.263 |
# +-------------+-------+
# ['great_ne(A,B) :-   x_subst(A,C,D), ring_subst_2(A,E).', 'great_ne(A,B) :-   ring_subst_3(A,C), ring_subst_4(B,D).', 'great_ne(A,B) :-   r_subst_3(B,C), ring_substitutions(A,D).', 'great_ne(A,B) :-   ring_subst_5(B,C).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 68        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 7                | 8                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 23               | 30               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.544 |
# +-------------+-------+
# | Precision   | 0.467 |
# +-------------+-------+
# | Sensitivity | 0.233 |
# +-------------+-------+
# | Specificity | 0.789 |
# +-------------+-------+
# | F1 Score    | 0.311 |
# +-------------+-------+
# ['great_ne(A,B) :-   x_subst(B,C,D), ring_subst_4(B,E).', 'great_ne(A,B) :-   ring_subst_3(A,C), ring_subst_4(B,D).', 'great_ne(A,B) :-   ring_subst_2(A,C), ring_subst_3(B,D).', 'great_ne(A,B) :-   ring_subst_5(B,C).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 68        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 8                | 5                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 22               | 33               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.603 |
# +-------------+-------+
# | Precision   | 0.615 |
# +-------------+-------+
# | Sensitivity | 0.267 |
# +-------------+-------+
# | Specificity | 0.868 |
# +-------------+-------+
# | F1 Score    | 0.372 |
# +-------------+-------+
# ['great_ne(A,B) :-   x_subst(B,C,D), ring_subst_4(B,E).', 'great_ne(A,B) :-   ring_subst_3(A,C), ring_subst_4(B,D).', 'great_ne(A,B) :-   ring_subst_2(A,C), ring_subst_3(B,D).', 'great_ne(A,B) :-   r_subst_3(B,C), ring_substitutions(A,D).', 'great_ne(A,B) :-   ring_subst_5(B,C).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 67        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 7                | 8                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 23               | 29               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.537 |
# +-------------+-------+
# | Precision   | 0.467 |
# +-------------+-------+
# | Sensitivity | 0.233 |
# +-------------+-------+
# | Specificity | 0.784 |
# +-------------+-------+
# | F1 Score    | 0.311 |
# +-------------+-------+

# %% [markdown]
# # System 2 - Metagol_NT

# %%
model_metagol=metagolnt_cross_validation(file="BK_metagol.pl", positive_example="pos_example.f", 
                                         negative_example="neg_example.n", CV=10,  shuffle=True,
                                         num_pos=2, num_neg=2, max_run=30)
# Out:
# (['great_ne(A,B):-ring_substitutions(B,5),alk_groups(A,1)', 'great_ne(A,B):-alk_groups(B,0),alk_groups(A,1)'], 0.651)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 6                | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 25               | 37               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.623 |
# +-------------+-------+
# | Precision   | 0.857 |
# +-------------+-------+
# | Sensitivity | 0.194 |
# +-------------+-------+
# | Specificity | 0.974 |
# +-------------+-------+
# | F1 Score    | 0.316 |
# +-------------+-------+
# (['great_ne(A,B):-ring_substitutions(B,5),alk_groups(A,1)', 'great_ne(A,B):-alk_groups(B,0),alk_groups(A,1)'], 0.649)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 7                | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 24               | 37               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.638 |
# +-------------+-------+
# | Precision   | 0.875 |
# +-------------+-------+
# | Sensitivity | 0.226 |
# +-------------+-------+
# | Specificity | 0.974 |
# +-------------+-------+
# | F1 Score    | 0.359 |
# +-------------+-------+
# (['great_ne(A,B):-ring_substitutions(B,5),alk_groups(A,1)', 'great_ne(A,B):-alk_groups(B,0),alk_groups(A,1)'], 0.654)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 5                | 2                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 26               | 36               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.594 |
# +-------------+-------+
# | Precision   | 0.714 |
# +-------------+-------+
# | Sensitivity | 0.161 |
# +-------------+-------+
# | Specificity | 0.947 |
# +-------------+-------+
# | F1 Score    | 0.263 |
# +-------------+-------+
# (['great_ne(A,B):-alk_groups(B,0),alk_groups(A,1)', 'great_ne(A,B):-alk_groups(B,2),alk_groups(A,1)'], 0.641)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 6                | 2                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 25               | 36               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.609 |
# +-------------+-------+
# | Precision   | 0.750 |
# +-------------+-------+
# | Sensitivity | 0.194 |
# +-------------+-------+
# | Specificity | 0.947 |
# +-------------+-------+
# | F1 Score    | 0.308 |
# +-------------+-------+
# (['great_ne(A,B):-alk_groups(B,0),alk_groups(A,1)', 'great_ne(A,B):-alk_groups(B,2),alk_groups(A,1)'], 0.638)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 9                | 3                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 22               | 35               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.638 |
# +-------------+-------+
# | Precision   | 0.750 |
# +-------------+-------+
# | Sensitivity | 0.290 |
# +-------------+-------+
# | Specificity | 0.921 |
# +-------------+-------+
# | F1 Score    | 0.419 |
# +-------------+-------+
# (['great_ne(A,B):-alk_groups(B,1),ring_subst_4(A,cf3)', 'great_ne(A,B):-alk_groups(B,0),alk_groups(A,1)'], 0.636)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 8                | 2                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 23               | 36               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.638 |
# +-------------+-------+
# | Precision   | 0.800 |
# +-------------+-------+
# | Sensitivity | 0.258 |
# +-------------+-------+
# | Specificity | 0.947 |
# +-------------+-------+
# | F1 Score    | 0.390 |
# +-------------+-------+
# (['great_ne(A,B):-alk_groups(B,1),ring_subst_4(A,cf3)', 'great_ne(A,B):-alk_groups(B,0),alk_groups(A,1)'], 0.635)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 69        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 9                | 2                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 22               | 36               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.652 |
# +-------------+-------+
# | Precision   | 0.818 |
# +-------------+-------+
# | Sensitivity | 0.290 |
# +-------------+-------+
# | Specificity | 0.947 |
# +-------------+-------+
# | F1 Score    | 0.429 |
# +-------------+-------+
# (['great_ne(A,B):-alk_groups(B,0),alk_groups(A,1)', 'great_ne(A,B):-alk_groups(B,1),ring_subst_2(A,ch3)'], 0.64)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 68        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 12               | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 18               | 37               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.721 |
# +-------------+-------+
# | Precision   | 0.923 |
# +-------------+-------+
# | Sensitivity | 0.400 |
# +-------------+-------+
# | Specificity | 0.974 |
# +-------------+-------+
# | F1 Score    | 0.558 |
# +-------------+-------+
# (['great_ne(A,B):-alk_groups(B,1),ring_subst_4(A,cf3)', 'great_ne(A,B):-alk_groups(B,0),alk_groups(A,1)'], 0.63)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 68        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 9                | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 21               | 38               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.691 |
# +-------------+-------+
# | Precision   | 1     |
# +-------------+-------+
# | Sensitivity | 0.300 |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0.462 |
# +-------------+-------+
# (['great_ne(A,B):-alk_groups(B,1),ring_subst_2(A,ch3)', 'great_ne(A,B):-alk_groups(B,0),alk_groups(A,1)'], 0.647)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 67        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 9                | 2                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 21               | 35               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.657 |
# +-------------+-------+
# | Precision   | 0.818 |
# +-------------+-------+
# | Sensitivity | 0.300 |
# +-------------+-------+
# | Specificity | 0.946 |
# +-------------+-------+
# | F1 Score    | 0.439 |
# +-------------+-------+

# %% [markdown]
# # System 3 - PyGol

# %%
constant_1=[]
P, N = bottom_clause_generation(file="BK.pl",constant_set = constant_1,   container = "dict", depth=2, 
                                positive_example="pos_example.f", negative_example="neg_example.n")
folds=pygol_folds(folds=10, shuffle=True)
model_pygol=pygol_cross_validation(folds, file="BK.pl", k_fold=10, min_pos=10, constant_set=constant_1, 
                              max_literals=2,   key_size=2,  max_neg=10)
# Out:
# 100%|██████████| 307/307 [00:00<00:00, 433.34it/s]
# 100%|██████████| 379/379 [00:00<00:00, 440.50it/s]
# 100%|██████████| 276/276 [00:03<00:00, 90.83it/s]
# 100%|██████████| 341/341 [00:03<00:00, 85.80it/s]
# +----------+ Hypothesis +----------+
# ['great_ne(A,B):-alk_groups(B,0),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,2),r_subst_2(A,C)', 'great_ne(A,B):-ring_subst_3(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,4),r_subst_2(A,C)', 'great_ne(A,B):-r_subst_1(A,C),ring_substitutions(B,5)', 'great_ne(A,B):-ring_subst_4(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,3),ring_substitutions(A,1)', 'great_ne(A,B):-alk_groups(B,3),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,3),r_subst_1(A,C)']
# +---------------------+------------------+------------------+
# |       n = 617       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 151              | 48               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 125              | 293              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.720 |
# +-------------+-------+
# | Precision   | 0.759 |
# +-------------+-------+
# | Sensitivity | 0.547 |
# +-------------+-------+
# | Specificity | 0.859 |
# +-------------+-------+
# | F1 Score    | 0.636 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 68        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 14               | 7                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 17               | 30               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.647 |
# +-------------+-------+
# | Precision   | 0.667 |
# +-------------+-------+
# | Sensitivity | 0.452 |
# +-------------+-------+
# | Specificity | 0.811 |
# +-------------+-------+
# | F1 Score    | 0.538 |
# +-------------+-------+
# 100%|██████████| 276/276 [00:00<00:00, 681.73it/s]
# 100%|██████████| 341/341 [00:00<00:00, 712.77it/s]
# +----------+ Hypothesis +----------+
# ['great_ne(A,B):-alk_groups(B,0),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,2),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,4),r_subst_2(A,C)', 'great_ne(A,B):-ring_subst_3(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(A,1),ring_substitutions(B,5)', 'great_ne(A,B):-alk_groups(B,3),ring_substitutions(A,1)', 'great_ne(A,B):-alk_groups(B,3),r_subst_2(A,C)', 'great_ne(A,B):-ring_subst_4(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,3),r_subst_1(A,C)']
# +---------------------+------------------+------------------+
# |       n = 617       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 143              | 45               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 133              | 296              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.712 |
# +-------------+-------+
# | Precision   | 0.761 |
# +-------------+-------+
# | Sensitivity | 0.518 |
# +-------------+-------+
# | Specificity | 0.868 |
# +-------------+-------+
# | F1 Score    | 0.616 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 68        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 20               | 5                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 11               | 32               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.765 |
# +-------------+-------+
# | Precision   | 0.800 |
# +-------------+-------+
# | Sensitivity | 0.645 |
# +-------------+-------+
# | Specificity | 0.865 |
# +-------------+-------+
# | F1 Score    | 0.714 |
# +-------------+-------+
# 100%|██████████| 276/276 [00:00<00:00, 1408306.45it/s]
# 100%|██████████| 341/341 [00:00<00:00, 961841.07it/s]
# +----------+ Hypothesis +----------+
# ['great_ne(A,B):-alk_groups(B,0),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,2),r_subst_2(A,C)', 'great_ne(A,B):-ring_subst_3(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,4),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(A,1),ring_substitutions(B,5)', 'great_ne(A,B):-ring_subst_4(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,3),ring_substitutions(A,1)', 'great_ne(A,B):-alk_groups(B,3),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,3),r_subst_1(A,C)']
# +---------------------+------------------+------------------+
# |       n = 617       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 146              | 45               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 130              | 296              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.716 |
# +-------------+-------+
# | Precision   | 0.764 |
# +-------------+-------+
# | Sensitivity | 0.529 |
# +-------------+-------+
# | Specificity | 0.868 |
# +-------------+-------+
# | F1 Score    | 0.625 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 68        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 17               | 5                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 14               | 32               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.721 |
# +-------------+-------+
# | Precision   | 0.773 |
# +-------------+-------+
# | Sensitivity | 0.548 |
# +-------------+-------+
# | Specificity | 0.865 |
# +-------------+-------+
# | F1 Score    | 0.642 |
# +-------------+-------+
# 100%|██████████| 276/276 [00:00<00:00, 1332137.98it/s]
# 100%|██████████| 341/341 [00:00<00:00, 1521550.71it/s]
# +----------+ Hypothesis +----------+
# ['great_ne(A,B):-alk_groups(B,0),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,4),r_subst_2(A,C)', 'great_ne(A,B):-ring_subst_3(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-r_subst_1(A,C),ring_substitutions(B,5)', 'great_ne(A,B):-alk_groups(B,3),ring_substitutions(A,1)', 'great_ne(A,B):-ring_subst_4(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,3),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,3),r_subst_1(A,C)']
# +---------------------+------------------+------------------+
# |       n = 617       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 135              | 39               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 141              | 302              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.708 |
# +-------------+-------+
# | Precision   | 0.776 |
# +-------------+-------+
# | Sensitivity | 0.489 |
# +-------------+-------+
# | Specificity | 0.886 |
# +-------------+-------+
# | F1 Score    | 0.600 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 68        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 18               | 7                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 13               | 30               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.706 |
# +-------------+-------+
# | Precision   | 0.720 |
# +-------------+-------+
# | Sensitivity | 0.581 |
# +-------------+-------+
# | Specificity | 0.811 |
# +-------------+-------+
# | F1 Score    | 0.643 |
# +-------------+-------+
# 100%|██████████| 276/276 [00:00<00:00, 1300705.51it/s]
# 100%|██████████| 341/341 [00:00<00:00, 880158.56it/s]
# +----------+ Hypothesis +----------+
# ['great_ne(A,B):-alk_groups(B,0),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,2),r_subst_1(A,C)', 'great_ne(A,B):-ring_subst_3(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,4),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(A,1),ring_substitutions(B,5)', 'great_ne(A,B):-alk_groups(B,3),ring_substitutions(A,1)', 'great_ne(A,B):-ring_subst_4(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,3),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,3),r_subst_1(A,C)']
# +---------------------+------------------+------------------+
# |       n = 617       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 150              | 48               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 126              | 293              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.718 |
# +-------------+-------+
# | Precision   | 0.758 |
# +-------------+-------+
# | Sensitivity | 0.543 |
# +-------------+-------+
# | Specificity | 0.859 |
# +-------------+-------+
# | F1 Score    | 0.633 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 68        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 13               | 5                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 18               | 32               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.662 |
# +-------------+-------+
# | Precision   | 0.722 |
# +-------------+-------+
# | Sensitivity | 0.419 |
# +-------------+-------+
# | Specificity | 0.865 |
# +-------------+-------+
# | F1 Score    | 0.531 |
# +-------------+-------+
# 100%|██████████| 276/276 [00:00<00:00, 885713.78it/s]
# 100%|██████████| 341/341 [00:00<00:00, 725650.77it/s]
# +----------+ Hypothesis +----------+
# ['great_ne(A,B):-alk_groups(B,0),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,2),r_subst_2(A,C)', 'great_ne(A,B):-ring_subst_3(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(A,1),ring_substitutions(B,5)', 'great_ne(A,B):-alk_groups(B,3),ring_substitutions(A,1)', 'great_ne(A,B):-alk_groups(B,3),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,3),r_subst_1(A,C)', 'great_ne(A,B):-ring_subst_4(B,C),ring_substitutions(A,0)']
# +---------------------+------------------+------------------+
# |       n = 617       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 135              | 35               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 141              | 306              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.715 |
# +-------------+-------+
# | Precision   | 0.794 |
# +-------------+-------+
# | Sensitivity | 0.489 |
# +-------------+-------+
# | Specificity | 0.897 |
# +-------------+-------+
# | F1 Score    | 0.605 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 68        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 16               | 4                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 15               | 33               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.721 |
# +-------------+-------+
# | Precision   | 0.800 |
# +-------------+-------+
# | Sensitivity | 0.516 |
# +-------------+-------+
# | Specificity | 0.892 |
# +-------------+-------+
# | F1 Score    | 0.627 |
# +-------------+-------+
# 100%|██████████| 276/276 [00:00<00:00, 1234144.89it/s]
# 100%|██████████| 341/341 [00:00<00:00, 963785.49it/s]
# +----------+ Hypothesis +----------+
# ['great_ne(A,B):-alk_groups(B,0),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,4),r_subst_1(A,C)', 'great_ne(A,B):-ring_subst_3(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,2),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(A,1),ring_substitutions(B,5)', 'great_ne(A,B):-alk_groups(B,3),ring_substitutions(A,1)', 'great_ne(A,B):-alk_groups(B,3),r_subst_2(A,C)', 'great_ne(A,B):-ring_subst_4(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,3),r_subst_1(A,C)']
# +---------------------+------------------+------------------+
# |       n = 617       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 149              | 45               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 127              | 296              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.721 |
# +-------------+-------+
# | Precision   | 0.768 |
# +-------------+-------+
# | Sensitivity | 0.540 |
# +-------------+-------+
# | Specificity | 0.868 |
# +-------------+-------+
# | F1 Score    | 0.634 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 68        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 14               | 5                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 17               | 32               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.676 |
# +-------------+-------+
# | Precision   | 0.737 |
# +-------------+-------+
# | Sensitivity | 0.452 |
# +-------------+-------+
# | Specificity | 0.865 |
# +-------------+-------+
# | F1 Score    | 0.560 |
# +-------------+-------+
# 100%|██████████| 277/277 [00:00<00:00, 1406564.42it/s]
# 100%|██████████| 341/341 [00:00<00:00, 1241543.11it/s]
# +----------+ Hypothesis +----------+
# ['great_ne(A,B):-alk_groups(B,0),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,4),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,2),r_subst_2(A,C)', 'great_ne(A,B):-ring_subst_3(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-r_subst_1(A,C),ring_substitutions(B,5)', 'great_ne(A,B):-ring_subst_4(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,3),ring_substitutions(A,1)', 'great_ne(A,B):-alk_groups(B,3),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,3),r_subst_1(A,C)']
# +---------------------+------------------+------------------+
# |       n = 618       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 147              | 46               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 130              | 295              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.715 |
# +-------------+-------+
# | Precision   | 0.762 |
# +-------------+-------+
# | Sensitivity | 0.531 |
# +-------------+-------+
# | Specificity | 0.865 |
# +-------------+-------+
# | F1 Score    | 0.626 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 67        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 18               | 7                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 12               | 30               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.716 |
# +-------------+-------+
# | Precision   | 0.720 |
# +-------------+-------+
# | Sensitivity | 0.600 |
# +-------------+-------+
# | Specificity | 0.811 |
# +-------------+-------+
# | F1 Score    | 0.655 |
# +-------------+-------+
# 100%|██████████| 277/277 [00:00<00:00, 863166.57it/s]
# 100%|██████████| 341/341 [00:00<00:00, 720896.00it/s]
# +----------+ Hypothesis +----------+
# ['great_ne(A,B):-alk_groups(B,0),r_subst_2(A,C)', 'great_ne(A,B):-ring_subst_3(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,2),r_subst_1(A,C)', 'great_ne(A,B):-alk_groups(B,4),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(A,1),ring_substitutions(B,5)', 'great_ne(A,B):-ring_subst_4(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,3),ring_substitutions(A,1)', 'great_ne(A,B):-alk_groups(B,3),r_subst_1(A,C)']
# +---------------------+------------------+------------------+
# |       n = 618       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 150              | 46               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 127              | 295              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.720 |
# +-------------+-------+
# | Precision   | 0.765 |
# +-------------+-------+
# | Sensitivity | 0.542 |
# +-------------+-------+
# | Specificity | 0.865 |
# +-------------+-------+
# | F1 Score    | 0.634 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 67        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 13               | 5                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 17               | 32               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.672 |
# +-------------+-------+
# | Precision   | 0.722 |
# +-------------+-------+
# | Sensitivity | 0.433 |
# +-------------+-------+
# | Specificity | 0.865 |
# +-------------+-------+
# | F1 Score    | 0.542 |
# +-------------+-------+
# 100%|██████████| 277/277 [00:00<00:00, 843734.36it/s]
# 100%|██████████| 342/342 [00:00<00:00, 1457776.39it/s]
# +----------+ Hypothesis +----------+
# ['great_ne(A,B):-alk_groups(B,0),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,2),r_subst_2(A,C)', 'great_ne(A,B):-ring_subst_3(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,4),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(A,1),ring_substitutions(B,5)', 'great_ne(A,B):-ring_subst_4(B,C),ring_substitutions(A,0)', 'great_ne(A,B):-alk_groups(B,3),ring_substitutions(A,1)', 'great_ne(A,B):-alk_groups(B,3),r_subst_2(A,C)', 'great_ne(A,B):-alk_groups(B,3),r_subst_1(A,C)']
# +---------------------+------------------+------------------+
# |       n = 619       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 148              | 43               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 129              | 299              |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.722 |
# +-------------+-------+
# | Precision   | 0.775 |
# +-------------+-------+
# | Sensitivity | 0.534 |
# +-------------+-------+
# | Specificity | 0.874 |
# +-------------+-------+
# | F1 Score    | 0.632 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 68        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 15               | 6                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 15               | 32               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.691 |
# +-------------+-------+
# | Precision   | 0.714 |
# +-------------+-------+
# | Sensitivity | 0.500 |
# +-------------+-------+
# | Specificity | 0.842 |
# +-------------+-------+
# | F1 Score    | 0.588 |
# +-------------+-------+

# %% [markdown]
# # System 4 - Progolem

# %%
# %%sh
# cat run_script.sh
# ./run_script.sh
# Out:
# yap -l run.pl > output.txt
# % Restoring file /usr/lib/Yap/startup.yss
# YAP 6.2.2 (x86_64-linux): Sat Sep 17 13:59:03 UTC 2016

# %%
model_progolem = metric_progolem()

# %% [markdown]
# # Evaluation Metrics

# %%
d = {'Pygol': [round(np.mean(model_pygol.accuracy),2), round(np.std(model_pygol.accuracy),1), 
               round(model_pygol.time_learn,2)],
'Metagol_NT': [round(np.mean(model_metagol.accuracy),2), round(np.std(model_metagol.accuracy),2),  
               round(model_metagol.time_learn,2)],
'ProGolem': [round(model_progolem['accuracy'],2), round(model_progolem['error'],2),
             round(model_progolem['time'],2)],
'Aleph': [round(np.mean(model_aleph.accuracy),2), round(np.std(model_aleph.accuracy),2), 
          round(model_aleph.time_learn,2)]
}
print ("{:<15} {:<10} {:<10} {:<10}".format('System','Accuracy','Std. Dev','Time'))
print ("{:<15} {:<10} {:<10} {:<10}".format('------','--------','-----','----'))
for k, v in d.items():
    lang, perc, change = v
    print ("{:<15} {:<10} {:<10} {:<10}".format(k, lang, perc, change))
# Out:
# System          Accuracy   Std. Dev   Time
# ------          --------   -----      ----
# Pygol           0.7        0.0        8.83
# Metagol_NT      0.65       0.04       19.11
# ProGolem        64.9       4.2        20.89
# Aleph           0.59       0.03       43.04
