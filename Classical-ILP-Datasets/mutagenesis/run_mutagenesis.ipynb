# %% [markdown]
# # Import Packages

# %%
from pygol import *
from  PyILP import *
from help_progolem import *

# %% [markdown]
# # Parameter Settings

# %%
"""
Clause Length = 4
Min. Pos      = 2
Max. Noise    = 5
Evl.Function  = coverage 
"""
# Out:
# '\nClause Length = 4\nMin. Pos      = 2\nMax. Noise    = 5\nEvl.Function  = coverage \n'

# %% [markdown]
# # System 1 - Aleph

# %%
model_aleph=aleph_cross_validation(file="BK.pl", settings="modes.pl",  CV=10,  positive_example="pos_example.f", 
                                       negative_example="neg_example.n")
# Out:
# ['active(A) :-   ind1(A,1.0).', 'active(A) :-   bond(A,B,C,1), bond(A,D,B,2), bond(A,B,E,2).', 'active(A) :-   bond(A,B,C,2), bond(A,C,D,1), ring_size_5(A,E).', 'active(A) :-   atm(A,B,n,34,C), atm(A,D,n,34,C), bond(A,B,D,7).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 20        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 10               | 2                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 3                | 5                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.750 |
# +-------------+-------+
# | Precision   | 0.833 |
# +-------------+-------+
# | Sensitivity | 0.769 |
# +-------------+-------+
# | Specificity | 0.714 |
# +-------------+-------+
# | F1 Score    | 0.800 |
# +-------------+-------+
# ['active(A) :-   ind1(A,1.0).', 'active(A) :-   bond(A,B,C,2), bond(A,C,D,1), ring_size_5(A,E).', 'active(A) :-   atm(A,B,n,34,C), atm(A,D,n,34,C), bond(A,B,D,7).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 20        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 13               | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 6                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.950 |
# +-------------+-------+
# | Precision   | 0.929 |
# +-------------+-------+
# | Sensitivity | 1     |
# +-------------+-------+
# | Specificity | 0.857 |
# +-------------+-------+
# | F1 Score    | 0.963 |
# +-------------+-------+
# ['active(A) :-   ind1(A,1.0).', 'active(A) :-   atm(A,B,c,29,C), bond(A,D,E,1), bond(A,F,D,2).', 'active(A) :-   bond(A,B,C,2), bond(A,C,D,1), ring_size_5(A,E).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 20        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 10               | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 3                | 6                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.800 |
# +-------------+-------+
# | Precision   | 0.909 |
# +-------------+-------+
# | Sensitivity | 0.769 |
# +-------------+-------+
# | Specificity | 0.857 |
# +-------------+-------+
# | F1 Score    | 0.833 |
# +-------------+-------+
# ['active(A) :-   ind1(A,1.0).', 'active(A) :-   atm(A,B,c,29,C), bond(A,D,E,1), bond(A,F,D,2).', 'active(A) :-   atm(A,B,c,16,C), ring_size_5(A,D).', 'active(A) :-   atm(A,B,n,34,C), atm(A,D,n,34,C), bond(A,B,D,7).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 19        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 12               | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 1                | 5                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.895 |
# +-------------+-------+
# | Precision   | 0.923 |
# +-------------+-------+
# | Sensitivity | 0.923 |
# +-------------+-------+
# | Specificity | 0.833 |
# +-------------+-------+
# | F1 Score    | 0.923 |
# +-------------+-------+
# ['active(A) :-   ind1(A,1.0).', 'active(A) :-   bond(A,B,C,2), bond(A,C,D,1), ring_size_5(A,E).', 'active(A) :-   atm(A,B,n,34,C), atm(A,D,n,34,C), bond(A,B,D,7).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 19        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 12               | 2                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 1                | 4                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.842 |
# +-------------+-------+
# | Precision   | 0.857 |
# +-------------+-------+
# | Sensitivity | 0.923 |
# +-------------+-------+
# | Specificity | 0.667 |
# +-------------+-------+
# | F1 Score    | 0.889 |
# +-------------+-------+
# ['active(A) :-   ind1(A,1.0).', 'active(A) :-   atm(A,B,c,29,C), bond(A,D,E,1), bond(A,F,D,2).', 'active(A) :-   bond(A,B,C,2), bond(A,C,D,1), ring_size_5(A,E).', 'active(A) :-   atm(A,B,n,34,C), atm(A,D,n,34,C), bond(A,B,D,7).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 12               | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 6                |
# +---------------------+------------------+------------------+
# +-------------+---+
# |   Metric    | # |
# +=============+===+
# | Accuracy    | 1 |
# +-------------+---+
# | Precision   | 1 |
# +-------------+---+
# | Sensitivity | 1 |
# +-------------+---+
# | Specificity | 1 |
# +-------------+---+
# | F1 Score    | 1 |
# +-------------+---+
# ['active(A) :-   ind1(A,1.0).', 'active(A) :-   atm(A,B,c,29,C), atm(A,D,n,38,E), bond(A,D,F,1).', 'active(A) :-   bond(A,B,C,2), bond(A,C,D,1), ring_size_5(A,E).', 'active(A) :-   atm(A,B,n,34,C), atm(A,D,n,34,C), bond(A,B,D,7).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 10               | 2                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 2                | 4                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.778 |
# +-------------+-------+
# | Precision   | 0.833 |
# +-------------+-------+
# | Sensitivity | 0.833 |
# +-------------+-------+
# | Specificity | 0.667 |
# +-------------+-------+
# | F1 Score    | 0.833 |
# +-------------+-------+
# ['active(A) :-   ind1(A,1.0).', 'active(A) :-   bond(A,B,C,2), bond(A,C,D,1), ring_size_5(A,E).', 'active(A) :-   atm(A,B,n,34,C), atm(A,D,n,34,C), bond(A,B,D,7).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 11               | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 1                | 5                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.889 |
# +-------------+-------+
# | Precision   | 0.917 |
# +-------------+-------+
# | Sensitivity | 0.917 |
# +-------------+-------+
# | Specificity | 0.833 |
# +-------------+-------+
# | F1 Score    | 0.917 |
# +-------------+-------+
# ['active(A) :-   ind1(A,1.0).', 'active(A) :-   atm(A,B,c,29,C), bond(A,D,E,1), bond(A,F,D,2).', 'active(A) :-   bond(A,B,C,2), bond(A,C,D,1), ring_size_5(A,E).', 'active(A) :-   atm(A,B,n,34,C), atm(A,D,n,34,C), bond(A,B,D,7).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 11               | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 1                | 5                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.889 |
# +-------------+-------+
# | Precision   | 0.917 |
# +-------------+-------+
# | Sensitivity | 0.917 |
# +-------------+-------+
# | Specificity | 0.833 |
# +-------------+-------+
# | F1 Score    | 0.917 |
# +-------------+-------+
# ['active(A) :-   ind1(A,1.0).', 'active(A) :-   atm(A,B,c,29,C), bond(A,D,E,1), bond(A,F,D,2).', 'active(A) :-   bond(A,B,C,2), bond(A,C,D,1), ring_size_5(A,E).']
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 11               | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 1                | 6                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.944 |
# +-------------+-------+
# | Precision   | 1     |
# +-------------+-------+
# | Sensitivity | 0.917 |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0.957 |
# +-------------+-------+

# %% [markdown]
# # System 2 - Metagol_NT

# %%
model_metagol=metagolnt_cross_validation(file="BK_metagol.pl", positive_example="pos_example.f", 
                                         negative_example="neg_example.n", CV=10, shuffle=True,  
                                         num_pos=2, num_neg=2, max_run=30)
# Out:
# (['active(A):-lumo(A,-1.932)', 'active(A):-ind1(A,1.0)'], 0.848)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 20        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 9                | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 4                | 7                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.800 |
# +-------------+-------+
# | Precision   | 1     |
# +-------------+-------+
# | Sensitivity | 0.692 |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0.818 |
# +-------------+-------+
# (['active(A):-lumo(A,-1.932)', 'active(A):-ind1(A,1.0)'], 0.854)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 20        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 10               | 2                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 3                | 5                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.750 |
# +-------------+-------+
# | Precision   | 0.833 |
# +-------------+-------+
# | Sensitivity | 0.769 |
# +-------------+-------+
# | Specificity | 0.714 |
# +-------------+-------+
# | F1 Score    | 0.800 |
# +-------------+-------+
# (['active(A):-lumo(A,-1.932)', 'active(A):-ind1(A,1.0)'], 0.823)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 20        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 13               | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 7                |
# +---------------------+------------------+------------------+
# +-------------+---+
# |   Metric    | # |
# +=============+===+
# | Accuracy    | 1 |
# +-------------+---+
# | Precision   | 1 |
# +-------------+---+
# | Sensitivity | 1 |
# +-------------+---+
# | Specificity | 1 |
# +-------------+---+
# | F1 Score    | 1 |
# +-------------+---+
# (['active(A):-lumo(A,-1.411)', 'active(A):-ind1(A,1.0)'], 0.836)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 19        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 11               | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 2                | 6                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.895 |
# +-------------+-------+
# | Precision   | 1     |
# +-------------+-------+
# | Sensitivity | 0.846 |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0.917 |
# +-------------+-------+
# (['active(A):-lumo(A,-1.411)', 'active(A):-ind1(A,1.0)'], 0.842)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 19        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 10               | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 3                | 6                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.842 |
# +-------------+-------+
# | Precision   | 1     |
# +-------------+-------+
# | Sensitivity | 0.769 |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0.870 |
# +-------------+-------+
# (['active(A):-lumo(A,-1.411)', 'active(A):-ind1(A,1.0)'], 0.843)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 9                | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 3                | 6                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.833 |
# +-------------+-------+
# | Precision   | 1     |
# +-------------+-------+
# | Sensitivity | 0.750 |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0.857 |
# +-------------+-------+
# (['active(A):-lumo(A,-1.411)', 'active(A):-ind1(A,1.0)'], 0.837)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 11               | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 1                | 5                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.889 |
# +-------------+-------+
# | Precision   | 0.917 |
# +-------------+-------+
# | Sensitivity | 0.917 |
# +-------------+-------+
# | Specificity | 0.833 |
# +-------------+-------+
# | F1 Score    | 0.917 |
# +-------------+-------+
# (['active(A):-lumo(A,-1.411)', 'active(A):-ind1(A,1.0)'], 0.843)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 9                | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 3                | 6                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.833 |
# +-------------+-------+
# | Precision   | 1     |
# +-------------+-------+
# | Sensitivity | 0.750 |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0.857 |
# +-------------+-------+
# (['active(A):-lumo(A,-1.411)', 'active(A):-ind1(A,1.0)'], 0.849)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 8                | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 4                | 6                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.778 |
# +-------------+-------+
# | Precision   | 1     |
# +-------------+-------+
# | Sensitivity | 0.667 |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0.800 |
# +-------------+-------+
# (['active(A):-lumo(A,-1.411)', 'active(A):-ind1(A,1.0)'], 0.849)
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 9                | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 3                | 5                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.778 |
# +-------------+-------+
# | Precision   | 0.900 |
# +-------------+-------+
# | Sensitivity | 0.750 |
# +-------------+-------+
# | Specificity | 0.833 |
# +-------------+-------+
# | F1 Score    | 0.818 |
# +-------------+-------+

# %% [markdown]
# # System 3 - PyGol

# %%
constant_1=['a','c','h','o','n','cl']
P, N = bottom_clause_generation(file="BK.pl",constant_set = constant_1,  container = "dict",
                                positive_example="pos_example.f", negative_example="neg_example.n")
folds=pygol_folds(folds=10, shuffle=True)
model_pygol=pygol_cross_validation(folds, file="BK.pl",  k_fold=10, min_pos=2,  
                             constant_set=constant_1, max_literals=3, set_chain=True, 
                                   max_neg=5)
# Out:
# 100%|██████████| 125/125 [00:05<00:00, 23.91it/s]
# 100%|██████████| 63/63 [00:01<00:00, 32.02it/s]
# 100%|██████████| 112/112 [00:30<00:00,  3.70it/s]
# 100%|██████████| 56/56 [00:07<00:00,  7.78it/s]
# +----------+ Hypothesis +----------+
# ['active(A):-ind1(A,1.0)', 'active(A):-atm(A,B,h,3,0.108),bond(A,C,D,1)', 'active(A):-logp(A,3)', 'active(A):-atm(A,B,o,40,-0.384),bond(A,B,C,2)', 'active(A):-atm(A,B,c,26,0.115),bond(A,C,D,7)', 'active(A):-atm(A,B,c,10,-0.096),bond(A,C,D,7)', 'active(A):-atm(A,B,c,29,0.014),bond(A,C,D,1)', 'active(A):-logp(A,1.49)', 'active(A):-atm(A,B,o,40,-0.39),bond(A,B,C,2)', 'active(A):-logp(A,2.52)', 'active(A):-atm(A,B,n,38,0.817),bond(A,C,D,2)']
# +---------------------+------------------+------------------+
# |       n = 168       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 108              | 8                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 4                | 48               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.929 |
# +-------------+-------+
# | Precision   | 0.931 |
# +-------------+-------+
# | Sensitivity | 0.964 |
# +-------------+-------+
# | Specificity | 0.857 |
# +-------------+-------+
# | F1 Score    | 0.947 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 19        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 12               | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 1                | 5                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.895 |
# +-------------+-------+
# | Precision   | 0.923 |
# +-------------+-------+
# | Sensitivity | 0.923 |
# +-------------+-------+
# | Specificity | 0.833 |
# +-------------+-------+
# | F1 Score    | 0.923 |
# +-------------+-------+
# 100%|██████████| 112/112 [00:03<00:00, 32.41it/s]
# 100%|██████████| 56/56 [00:00<00:00, 64.32it/s]
# +----------+ Hypothesis +----------+
# ['active(A):-ind1(A,1.0)', 'active(A):-atm(A,B,h,3,0.108)', 'active(A):-atm(A,B,c,22,-0.12),bond(A,B,C,1)', 'active(A):-atm(A,B,c,10,-0.096),bond(A,B,C,1)', 'active(A):-atm(A,B,c,26,0.315),bond(A,C,D,2)', 'active(A):-atm(A,B,n,38,0.817),bond(A,C,B,1)', 'active(A):-logp(A,3)', 'active(A):-atm(A,B,c,29,0.014)', 'active(A):-logp(A,2.52)']
# +---------------------+------------------+------------------+
# |       n = 168       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 107              | 10               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 5                | 46               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.911 |
# +-------------+-------+
# | Precision   | 0.915 |
# +-------------+-------+
# | Sensitivity | 0.955 |
# +-------------+-------+
# | Specificity | 0.821 |
# +-------------+-------+
# | F1 Score    | 0.934 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 19        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 13               | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 6                |
# +---------------------+------------------+------------------+
# +-------------+---+
# |   Metric    | # |
# +=============+===+
# | Accuracy    | 1 |
# +-------------+---+
# | Precision   | 1 |
# +-------------+---+
# | Sensitivity | 1 |
# +-------------+---+
# | Specificity | 1 |
# +-------------+---+
# | F1 Score    | 1 |
# +-------------+---+
# 100%|██████████| 112/112 [00:00<00:00, 661636.69it/s]
# 100%|██████████| 56/56 [00:00<00:00, 274714.65it/s]
# +----------+ Hypothesis +----------+
# ['active(A):-ind1(A,1.0)', 'active(A):-atm(A,B,h,3,0.14),bond(A,C,D,7)', 'active(A):-atm(A,B,o,40,-0.384),bond(A,B,C,2)', 'active(A):-logp(A,3)', 'active(A):-atm(A,B,h,1,0.315),bond(A,C,D,7)', 'active(A):-atm(A,B,c,22,-0.116),bond(A,C,B,1)', 'active(A):-logp(A,1.49)', 'active(A):-atm(A,B,c,16,-0.191),bond(A,C,D,2)', 'active(A):-atm(A,B,o,40,-0.389),bond(A,B,C,2)', 'active(A):-logp(A,2.52)', 'active(A):-atm(A,B,c,29,0.014),bond(A,C,D,2)', 'active(A):-atm(A,B,n,38,0.817),bond(A,C,B,2)']
# +---------------------+------------------+------------------+
# |       n = 168       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 106              | 7                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 6                | 49               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.923 |
# +-------------+-------+
# | Precision   | 0.938 |
# +-------------+-------+
# | Sensitivity | 0.946 |
# +-------------+-------+
# | Specificity | 0.875 |
# +-------------+-------+
# | F1 Score    | 0.942 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 19        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 12               | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 1                | 5                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.895 |
# +-------------+-------+
# | Precision   | 0.923 |
# +-------------+-------+
# | Sensitivity | 0.923 |
# +-------------+-------+
# | Specificity | 0.833 |
# +-------------+-------+
# | F1 Score    | 0.923 |
# +-------------+-------+
# 100%|██████████| 112/112 [00:00<00:00, 652447.29it/s]
# 100%|██████████| 57/57 [00:00<00:00, 513037.18it/s]
# +----------+ Hypothesis +----------+
# ['active(A):-ind1(A,1.0)', 'active(A):-atm(A,B,c,29,0.014),bond(A,C,B,7)', 'active(A):-atm(A,B,h,3,0.14),bond(A,C,D,1)', 'active(A):-atm(A,B,h,3,0.108),bond(A,C,B,1)', 'active(A):-atm(A,B,o,40,-0.384),bond(A,B,C,2)', 'active(A):-atm(A,B,c,26,0.315),bond(A,C,D,2)', 'active(A):-atm(A,B,o,40,-0.403)', 'active(A):-logp(A,3)', 'active(A):-atm(A,B,c,10,-0.096),bond(A,C,D,2)', 'active(A):-logp(A,1.49)', 'active(A):-atm(A,B,c,27,0.016),bond(A,C,D,2)', 'active(A):-atm(A,B,n,38,0.817),bond(A,B,C,1)']
# +---------------------+------------------+------------------+
# |       n = 169       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 109              | 10               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 3                | 47               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.923 |
# +-------------+-------+
# | Precision   | 0.916 |
# +-------------+-------+
# | Sensitivity | 0.973 |
# +-------------+-------+
# | Specificity | 0.825 |
# +-------------+-------+
# | F1 Score    | 0.944 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 19        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 11               | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 2                | 5                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.842 |
# +-------------+-------+
# | Precision   | 0.917 |
# +-------------+-------+
# | Sensitivity | 0.846 |
# +-------------+-------+
# | Specificity | 0.833 |
# +-------------+-------+
# | F1 Score    | 0.880 |
# +-------------+-------+
# 100%|██████████| 112/112 [00:00<00:00, 1025681.33it/s]
# 100%|██████████| 57/57 [00:00<00:00, 632474.41it/s]
# +----------+ Hypothesis +----------+
# ['active(A):-ind1(A,1.0)', 'active(A):-atm(A,B,h,3,0.108),bond(A,C,D,1)', 'active(A):-atm(A,B,h,3,0.115),bond(A,C,D,2)', 'active(A):-logp(A,3)', 'active(A):-atm(A,B,c,27,0.016)', 'active(A):-atm(A,B,c,22,-0.116),bond(A,C,B,1)', 'active(A):-logp(A,1.49)', 'active(A):-atm(A,B,n,38,0.81),bond(A,C,D,2)', 'active(A):-atm(A,B,n,38,0.814),bond(A,C,D,2)', 'active(A):-atm(A,B,n,38,0.817),bond(A,B,C,1)', 'active(A):-logp(A,2.52)', 'active(A):-logp(A,4.18)']
# +---------------------+------------------+------------------+
# |       n = 169       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 109              | 11               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 3                | 46               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.917 |
# +-------------+-------+
# | Precision   | 0.908 |
# +-------------+-------+
# | Sensitivity | 0.973 |
# +-------------+-------+
# | Specificity | 0.807 |
# +-------------+-------+
# | F1 Score    | 0.940 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 19        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 11               | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 2                | 6                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.895 |
# +-------------+-------+
# | Precision   | 1     |
# +-------------+-------+
# | Sensitivity | 0.846 |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0.917 |
# +-------------+-------+
# 100%|██████████| 113/113 [00:00<00:00, 440479.88it/s]
# 100%|██████████| 57/57 [00:00<00:00, 433107.48it/s]
# +----------+ Hypothesis +----------+
# ['active(A):-ind1(A,1.0)', 'active(A):-atm(A,B,h,3,0.14),bond(A,C,B,1)', 'active(A):-logp(A,3)', 'active(A):-atm(A,B,c,22,0.004),bond(A,B,C,1)', 'active(A):-logp(A,1.49)', 'active(A):-atm(A,B,c,22,0.108)', 'active(A):-atm(A,B,h,3,0.115),bond(A,C,D,7)', 'active(A):-atm(A,B,c,22,-0.116),bond(A,C,B,1)', 'active(A):-atm(A,B,c,27,0.016),bond(A,C,B,7)', 'active(A):-atm(A,B,c,29,0.014),bond(A,B,C,1)', 'active(A):-logp(A,2.52)']
# +---------------------+------------------+------------------+
# |       n = 170       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 108              | 8                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 5                | 49               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.924 |
# +-------------+-------+
# | Precision   | 0.931 |
# +-------------+-------+
# | Sensitivity | 0.956 |
# +-------------+-------+
# | Specificity | 0.860 |
# +-------------+-------+
# | F1 Score    | 0.943 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 10               | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 2                | 6                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.889 |
# +-------------+-------+
# | Precision   | 1     |
# +-------------+-------+
# | Sensitivity | 0.833 |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0.909 |
# +-------------+-------+
# 100%|██████████| 113/113 [00:00<00:00, 394634.76it/s]
# 100%|██████████| 57/57 [00:00<00:00, 338154.64it/s]
# +----------+ Hypothesis +----------+
# ['active(A):-ind1(A,1.0)', 'active(A):-atm(A,B,c,22,-0.12)', 'active(A):-logp(A,2.74)', 'active(A):-atm(A,B,o,40,-0.384),bond(A,B,C,2)', 'active(A):-atm(A,B,c,26,0.115),bond(A,C,D,7)', 'active(A):-atm(A,B,c,10,-0.096),bond(A,C,D,2)', 'active(A):-atm(A,B,o,40,-0.386),bond(A,B,C,2)', 'active(A):-logp(A,1.49)', 'active(A):-atm(A,B,c,29,0.014),bond(A,B,C,1)', 'active(A):-logp(A,2.52)', 'active(A):-logp(A,3)', 'active(A):-atm(A,B,n,38,0.817),bond(A,C,B,2)']
# +---------------------+------------------+------------------+
# |       n = 170       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 106              | 8                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 7                | 49               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.912 |
# +-------------+-------+
# | Precision   | 0.930 |
# +-------------+-------+
# | Sensitivity | 0.938 |
# +-------------+-------+
# | Specificity | 0.860 |
# +-------------+-------+
# | F1 Score    | 0.934 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 12               | 1                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 5                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.944 |
# +-------------+-------+
# | Precision   | 0.923 |
# +-------------+-------+
# | Sensitivity | 1     |
# +-------------+-------+
# | Specificity | 0.833 |
# +-------------+-------+
# | F1 Score    | 0.960 |
# +-------------+-------+
# 100%|██████████| 113/113 [00:00<00:00, 622807.30it/s]
# 100%|██████████| 57/57 [00:00<00:00, 433107.48it/s]
# +----------+ Hypothesis +----------+
# ['active(A):-ind1(A,1.0)', 'active(A):-atm(A,B,h,3,0.14),bond(A,C,D,1)', 'active(A):-atm(A,B,h,3,0.108),bond(A,C,B,1)', 'active(A):-atm(A,B,c,22,0.004),bond(A,B,C,1)', 'active(A):-atm(A,B,c,26,0.315),bond(A,C,D,2)', 'active(A):-atm(A,B,n,38,0.814),bond(A,C,B,1)', 'active(A):-logp(A,1.49)', 'active(A):-logp(A,3)', 'active(A):-atm(A,B,c,27,0.016),bond(A,C,D,1)', 'active(A):-logp(A,2.52)', 'active(A):-atm(A,B,n,38,0.817),bond(A,C,B,2)']
# +---------------------+------------------+------------------+
# |       n = 170       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 109              | 8                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 4                | 49               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.929 |
# +-------------+-------+
# | Precision   | 0.932 |
# +-------------+-------+
# | Sensitivity | 0.965 |
# +-------------+-------+
# | Specificity | 0.860 |
# +-------------+-------+
# | F1 Score    | 0.948 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 11               | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 1                | 6                |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.944 |
# +-------------+-------+
# | Precision   | 1     |
# +-------------+-------+
# | Sensitivity | 0.917 |
# +-------------+-------+
# | Specificity | 1     |
# +-------------+-------+
# | F1 Score    | 0.957 |
# +-------------+-------+
# 100%|██████████| 113/113 [00:00<00:00, 947912.70it/s]
# 100%|██████████| 57/57 [00:00<00:00, 599186.29it/s]
# +----------+ Hypothesis +----------+
# ['active(A):-ind1(A,1.0)', 'active(A):-atm(A,B,c,22,-0.12),bond(A,B,C,1)', 'active(A):-atm(A,B,h,3,0.108),bond(A,C,D,2)', 'active(A):-atm(A,B,c,22,-0.116),bond(A,C,B,1)', 'active(A):-atm(A,B,h,1,0.315),bond(A,C,D,7)', 'active(A):-atm(A,B,n,38,0.817),bond(A,C,D,2)', 'active(A):-logp(A,3)', 'active(A):-atm(A,B,c,10,-0.096),bond(A,C,D,2)', 'active(A):-logp(A,2.52)', 'active(A):-atm(A,B,n,38,0.814),bond(A,C,D,2)']
# +---------------------+------------------+------------------+
# |       n = 170       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 108              | 10               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 5                | 47               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.912 |
# +-------------+-------+
# | Precision   | 0.915 |
# +-------------+-------+
# | Sensitivity | 0.956 |
# +-------------+-------+
# | Specificity | 0.825 |
# +-------------+-------+
# | F1 Score    | 0.935 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 12               | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 6                |
# +---------------------+------------------+------------------+
# +-------------+---+
# |   Metric    | # |
# +=============+===+
# | Accuracy    | 1 |
# +-------------+---+
# | Precision   | 1 |
# +-------------+---+
# | Sensitivity | 1 |
# +-------------+---+
# | Specificity | 1 |
# +-------------+---+
# | F1 Score    | 1 |
# +-------------+---+
# 100%|██████████| 113/113 [00:00<00:00, 675151.50it/s]
# 100%|██████████| 57/57 [00:00<00:00, 298471.07it/s]
# +----------+ Hypothesis +----------+
# ['active(A):-ind1(A,1.0)', 'active(A):-atm(A,B,h,3,0.14),bond(A,C,D,2)', 'active(A):-atm(A,B,h,3,0.108),bond(A,C,D,2)', 'active(A):-atm(A,B,c,10,-0.096),bond(A,C,D,7)', 'active(A):-atm(A,B,h,1,0.315),bond(A,C,D,7)', 'active(A):-atm(A,B,n,38,0.811),bond(A,C,D,2)', 'active(A):-atm(A,B,c,22,-0.116),bond(A,C,B,1)', 'active(A):-logp(A,3)', 'active(A):-logp(A,1.49)', 'active(A):-atm(A,B,c,29,0.014),bond(A,B,C,1)', 'active(A):-atm(A,B,c,27,0.016),bond(A,C,D,2)', 'active(A):-atm(A,B,n,38,0.817),bond(A,B,C,1)']
# +---------------------+------------------+------------------+
# |       n = 170       | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 109              | 11               |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 4                | 46               |
# +---------------------+------------------+------------------+
# +-------------+-------+
# |   Metric    |   #   |
# +=============+=======+
# | Accuracy    | 0.912 |
# +-------------+-------+
# | Precision   | 0.908 |
# +-------------+-------+
# | Sensitivity | 0.965 |
# +-------------+-------+
# | Specificity | 0.807 |
# +-------------+-------+
# | F1 Score    | 0.936 |
# +-------------+-------+
# +----------+ Testing +----------+
# +---------------------+------------------+------------------+
# |       n = 18        | Positive(Actual) | Negative(Actual) |
# +=====================+==================+==================+
# | Positive(Predicted) | 12               | 0                |
# +---------------------+------------------+------------------+
# | Negative(Predicted) | 0                | 6                |
# +---------------------+------------------+------------------+
# +-------------+---+
# |   Metric    | # |
# +=============+===+
# | Accuracy    | 1 |
# +-------------+---+
# | Precision   | 1 |
# +-------------+---+
# | Sensitivity | 1 |
# +-------------+---+
# | Specificity | 1 |
# +-------------+---+
# | F1 Score    | 1 |
# +-------------+---+

# %% [markdown]
# # System 4 - Progolem

# %%
# %%sh
# cat run_script.sh
# ./run_script.sh
# Out:
# yap -l run.pl > output.txt
# % Restoring file /usr/lib/Yap/startup.yss
# YAP 6.2.2 (x86_64-linux): Sat Sep 17 13:59:03 UTC 2016

# %%
model_progolem = metric_progolem()

# %% [markdown]
# # Evaluation Metrics

# %%
d = {'Pygol': [round(np.mean(model_pygol.accuracy),2), round(np.std(model_pygol.accuracy),1), 
               round(model_pygol.time_learn,2)],
'Metagol_NT': [round(np.mean(model_metagol.accuracy),2), round(np.std(model_metagol.accuracy),2),  
               round(model_metagol.time_learn,2)],
'ProGolem': [round(model_progolem['accuracy'],2), round(model_progolem['error'],2),
             round(model_progolem['time'],2)],
'Aleph': [round(np.mean(model_aleph.accuracy),2), round(np.std(model_aleph.accuracy),2), 
          round(model_aleph.time_learn,2)]
}
print ("{:<15} {:<10} {:<10} {:<10}".format('System','Accuracy','Std. Dev','Time'))
print ("{:<15} {:<10} {:<10} {:<10}".format('------','--------','-----','----'))
for k, v in d.items():
    lang, perc, change = v
    print ("{:<15} {:<10} {:<10} {:<10}".format(k, lang, perc, change))
# Out:
# System          Accuracy   Std. Dev   Time
# ------          --------   -----      ----
# Pygol           0.93       0.1        53.74
# Metagol_NT      0.84       0.07       211.74
# ProGolem        78.3       12.1       8.14
# Aleph           0.87       0.08       92.91

# %%
np.mean(model_pygol.accuracy)
# Out:
# 0.9304
